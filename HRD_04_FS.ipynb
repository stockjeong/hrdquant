# %% [markdown]
# # 양정고등학교 HRD 메이커 퀀트 실습 4
# ## 주요 재무지표 수집 및 가공하기
# [인증키 신청](https://opendart.fss.or.kr/uss/umt/EgovMberInsertView.do)

# %% [markdown]
# ### 1. 초기 세팅

# %%
! mkdir data

# %%
! wget https://raw.githubusercontent.com/stockjeong/hrdquant/refs/heads/main/%EC%A2%85%EB%AA%A9%EC%A0%95%EB%B3%B42025.csv # 샘플 데이터 받아오기
# Out:
# --2025-04-25 06:49:10--  https://github.com/stockjeong/hrdquant/2025stock.csv
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-04-25 06:49:10 ERROR 404: Not Found.

# %%
! pip install OpenDartReader -q

# %% [markdown]
# ### 2. 데이터 파싱 전략 수립

# %%
import OpenDartReader
my_api = "49526a379265e67332f8abb3ddc10ab9f6af07db"
dart = OpenDartReader(my_api)

# %%
import pandas as pd

stock_list = pd.read_csv(
    "./2024stock.csv",
    encoding="utf-8",
    sep="\t",
    usecols=["Name", "Code"],
    dtype=str)

# %%
report = dart.finstate("005380", 2023)
display(report[["fs_nm", "account_nm", "thstrm_amount", "frmtrm_amount", "bfefrmtrm_amount"]])
# Out:
#      fs_nm  account_nm        thstrm_amount        frmtrm_amount  \
# 0   연결재무제표        유동자산  101,724,717,000,000   96,389,273,000,000
# 1   연결재무제표       비유동자산  180,738,638,000,000  159,353,189,000,000
# 2   연결재무제표        자산총계  282,463,355,000,000  255,742,462,000,000
# 3   연결재무제표        유동부채   73,362,103,000,000   74,236,472,000,000
# 4   연결재무제표       비유동부채  107,291,812,000,000   90,609,445,000,000
# 5   연결재무제표        부채총계  180,653,915,000,000  164,845,917,000,000
# 6   연결재무제표         자본금    1,488,993,000,000    1,488,993,000,000
# 7   연결재무제표       이익잉여금   88,665,805,000,000   79,953,601,000,000
# 8   연결재무제표        자본총계  101,809,440,000,000   90,896,545,000,000
# 9   연결재무제표         매출액  162,663,579,000,000  142,151,469,000,000
# 10  연결재무제표        영업이익   15,126,901,000,000    9,824,928,000,000
# 11  연결재무제표  법인세차감전 순이익   17,618,662,000,000   11,181,471,000,000
# 12  연결재무제표       당기순이익   12,272,301,000,000    7,983,614,000,000
# 13  연결재무제표   당기순이익(손실)   12,272,301,000,000    7,983,614,000,000
# 14  연결재무제표       총포괄손익   12,428,841,000,000    9,034,476,000,000
# 15    재무제표        유동자산   21,797,281,000,000   23,819,313,000,000
# 16    재무제표       비유동자산   63,267,354,000,000   59,593,036,000,000
# 17    재무제표        자산총계   85,064,635,000,000   83,412,349,000,000
# 18    재무제표        유동부채   18,594,079,000,000   21,443,574,000,000
# 19    재무제표       비유동부채    5,683,387,000,000    6,212,960,000,000
# 20    재무제표        부채총계   24,277,466,000,000   27,656,534,000,000
# 21    재무제표         자본금    1,488,993,000,000    1,488,993,000,000
# 22    재무제표       이익잉여금   56,425,494,000,000   52,028,878,000,000
# 23    재무제표        자본총계   60,787,169,000,000   55,755,815,000,000
# 24    재무제표         매출액   78,033,758,000,000   65,308,350,000,000
# 25    재무제표        영업이익    6,670,971,000,000    2,828,569,000,000
# 26    재무제표  법인세차감전 순이익    9,675,202,000,000    4,175,475,000,000
# 27    재무제표       당기순이익    7,343,003,000,000    3,701,958,000,000
# 28    재무제표   당기순이익(손실)    7,343,003,000,000    3,701,958,000,000
# 29    재무제표       총포괄손익    7,120,747,000,000    3,950,212,000,000
#
#        bfefrmtrm_amount
# 0    88,565,366,000,000
# 1   145,381,049,000,000
# 2   233,946,415,000,000
# 3    64,236,787,000,000
# 4    87,093,839,000,000
# 5   151,330,626,000,000
# 6     1,488,993,000,000
# 7    73,167,855,000,000
# 8    82,615,789,000,000
# 9   116,448,159,000,000
# 10    6,526,521,000,000
# 11    7,789,043,000,000
# 12    5,693,077,000,000
# 13    5,693,077,000,000
# 14    7,861,139,000,000
# 15   23,330,493,000,000
# 16   56,427,807,000,000
# 17   79,758,300,000,000
# 18   20,043,791,000,000
# 19    7,039,497,000,000
# 20   27,083,288,000,000
# 21    1,488,993,000,000
# 22   49,094,270,000,000
# 23   52,675,012,000,000
# 24   55,605,120,000,000
# 25      661,623,000,000
# 26      989,847,000,000
# 27      645,526,000,000
# 28      645,526,000,000
# 29      775,156,000,000

# %% [markdown]
# ### 3. 데이터 파싱

# %% [markdown]
# #### 데이터 파싱 함수 작성

# %%
import numpy as np
import pandas as pd

def find_fins_ind_list(stock_code, stock_name, year, ind_list):
    try: # 데이터 가져오기
        report = None
        report = dart.finstate(stock_code, year)
    except:
        pass

    if report is None:  # 리포트가 없다면 (참고: 리포트가 없으면 None을 반환함)
        # 리포트가 없으면 당기, 전기, 전전기 값 모두 제거
        data = [[stock_name, year] + [np.nan] * len(ind_list)]
        data.append([stock_name, year - 1] + [np.nan] * len(ind_list))
        data.append([stock_name, year - 2] + [np.nan] * len(ind_list))

    else:
        report = report[report["account_nm"].isin(ind_list)]  # 관련 지표로 필터링
        if sum(report["fs_nm"] == "연결재무제표") > 0:
            # 연결재무제표 데이터가 있으면 연결재무제표를 사용
            report = report.loc[report["fs_nm"] == "연결재무제표"]
        else:
            # 연결재무제표 데이터가 없으면 일반재무제표를 사용
            report = report.loc[report["fs_nm"] == "재무제표"]
        data = []
        for y, c in zip([year, year - 1, year - 2],
                        ["thstrm_amount", "frmtrm_amount", "bfefrmtrm_amount"]):
            record = [stock_name, y]
            for ind in ind_list:
                # account_nm이 indic인 행의 c 컬럼 값을 가져옴
                if sum(report["account_nm"] == ind) > 0:
                    value = report.loc[report["account_nm"] == ind, c].iloc[0]
                else:
                    value = np.nan
                record.append(value)
            data.append(record)

    return pd.DataFrame(data, columns=["기업", "연도"] + ind_list)

# %%
ind_list = ['자산총계', '부채총계', '자본총계', '매출액', '영업이익', '당기순이익']
display(find_fins_ind_list("005930", "삼성전자", 2020, ind_list))
# Out:
#      기업    연도                 자산총계                 부채총계                 자본총계  \
# 0  삼성전자  2020  378,235,718,000,000  102,287,702,000,000  275,948,016,000,000
# 1  삼성전자  2019  352,564,497,000,000   89,684,076,000,000  262,880,421,000,000
# 2  삼성전자  2018  339,357,244,000,000   91,604,067,000,000  247,753,177,000,000
#
#                    매출액                영업이익               당기순이익
# 0  236,806,988,000,000  35,993,876,000,000  26,407,832,000,000
# 1  230,400,881,000,000  27,768,509,000,000  21,738,865,000,000
# 2  243,771,415,000,000  58,886,669,000,000  44,344,857,000,000

# %% [markdown]
# #### 데이터 수집

# %%
import time
data = pd.DataFrame() # 이 데이터프레임에 각각의 데이터를 추가할 예정
for code, name in stock_list[['Code', 'Name']].values:
    print(name)
    for year in [2023, 2024]:
        try:
            result = find_fins_ind_list(code, name, year, ind_list) # 재무지표 데이터
        except:
            pass

        data = pd.concat([data, result], axis = 0, ignore_index = True) # data에 부착
        time.sleep(0.5)
# Out:
# 삼성전자
# SK하이닉스
# LG에너지솔루션
# 삼성바이오로직스
# 삼성전자우
# 현대차
# 기아
# 셀트리온
# POSCO홀딩스
# NAVER
# 삼성SDI
# LG화학
# 삼성물산
# KB금융
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 현대모비스
# 신한지주
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 카카오
# 포스코퓨처엠
# 삼성생명
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하나금융지주
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 메리츠금융지주
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# LG전자
# 에코프로
# 삼성화재
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한국전력
# 한미반도체
# SK
# LG
# 카카오뱅크
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 크래프톤
# 삼성에스디에스
# 삼성전기
# KT&G
# SK이노베이션
# HLB
# SK텔레콤
# 두산에너빌리티
# HD현대중공업
# 한화에어로스페이스
# 기업은행
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# HMM
# SK스퀘어
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 우리금융지주
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 고려아연
# S-Oil
# 하이브
# KT
# 포스코인터내셔널
# HD한국조선해양
# 한화오션
# 에코프로머티
# 아모레퍼시픽
# 대한항공
# 삼성중공업
# HD현대일렉트릭
# SK바이오팜
# DB손해보험
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한국타이어앤테크놀로지
# 포스코DX
# 금양
# 현대글로비스
# 엔켐
# 엘앤에프
# LG생활건강
# 유한양행
# HD현대
# 맥쿼리인프라
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 현대차2우B
# SKC
# 롯데케미칼
# 두산밥캣
# LG디스플레이
# 삼성엔지니어링
# 넷마블
# 코스모신소재
# 카카오페이
# 한국항공우주
# 두산로보틱스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# CJ제일제당
# SK아이이테크놀로지
# 미래에셋증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# GS
# LG이노텍
# 한화솔루션
# SK바이오사이언스
# LG유플러스
# 현대제철
# 삼성카드
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 엔씨소프트
# 코웨이
# 현대로템
# 한미약품
# 한진칼
# 현대오토에버
# HPSP
# NH투자증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 오리온
# CJ
# 셀트리온제약
# 한국금융지주
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# LS
# 금호석유
# LIG넥스원
# 현대건설
# 현대차우
# LS ELECTRIC
# 쌍용C&E
# 삼성증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 레인보우로보틱스
# 강원랜드
# 키움증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한화시스템
# 한온시스템
# 신성델타테크
# 효성중공업
# 롯데지주
# F&F
# CJ대한통운
# 현대해상
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한미사이언스
# 삼천당제약
# 한전기술
# 이수페타시스
# 현대미포조선
# 동진쎄미켐
# BNK금융지주
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 솔브레인
# 한국가스공사
# 한화생명
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 씨에스윈드
# JB금융지주
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대한전선
# 호텔신라
# 아모레G
# 두산
# 한솔케미칼
# 농심
# KCC
# 휠라홀딩스
# 에스원
# 제일기획
# 롯데에너지머티리얼즈
# 팬오션
# ISC
# GS리테일
# 한화
# LG화학우
# BGF리테일
# 롯데쇼핑
# 위메이드
# DB하이텍
# 에스엠
# OCI홀딩스
# 이마트
# 동서
# 에이피알
# 영원무역
# LS머트리얼즈
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 이수스페셜티케미컬
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한올바이오파마
# 동원산업
# HLB생명과학
# 레이크머티리얼즈
# 신세계
# 금호타이어
# 삼양식품
# 루닛
# HD현대인프라코어
# 한전KPS
# 오뚜기
# 현대엘리베이
# 효성첨단소재
# 한국앤컴퍼니
# 대우건설
# HL만도
# 현대위아
# 더존비즈온
# 나노신소재
# 코스맥스
# 풍산
# 하이트진로
# 에스엘
# 효성티앤씨
# SK가스
# 덴티움
# TCC스틸
# DGB금융지주
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에스디바이오센서
# 파라다이스
# 대주전자재료
# 종근당
# DL이앤씨
# 스튜디오드래곤
# 대웅제약
# LX세미콘
# 녹십자
# 대덕전자
# 코스모화학
# 테크윙
# 코리안리
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# GS건설
# 두산퓨얼셀
# SK네트웍스
# 솔루엠
# 아프리카TV
# 더블유씨피
# 효성
# 씨젠
# 동원시스템즈
# 롯데칠성
# 현대백화점
# 한국콜마
# 파크시스템스
# 삼아알미늄
# 롯데정밀화학
# 가온칩스
# 케어젠
# KG모빌리티
# 메지온
# 롯데웰푸드
# HDC현대산업개발
# 영원무역홀딩스
# SK리츠
# 솔루스첨단소재
# 동화기업
# 에이비엘바이오
# 세방전지
# 한샘
# DL
# 에코프로에이치엔
# HD현대건설기계
# 대웅
# 오스코텍
# SK케미칼
# HLB테라퓨틱스
# 심텍
# LX인터내셔널
# 일진전기
# 메디톡스
# 성일하이텍
# 롯데렌탈
# SFA반도체
# 코오롱인더
# 차바이오텍
# 피에스케이홀딩스
# 제이앤티씨
# 파두
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# ESR켄달스퀘어리츠
# 에스앤에스텍
# 기가비스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대한유화
# 해성디에스
# 제주반도체
# 하나투어
# 세아제강지주
# 원텍
# 국일제지
# 오리온홀딩스
# 다우기술
# 롯데손해보험
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 미원상사
# 서진시스템
# 제주항공
# 넥슨게임즈
# HLB제약
# SK디스커버리
# 두산테스나
# 코오롱티슈진
# 더블유게임즈
# 율촌화학
# 포스코엠텍
# 이노션
# GKL
# 한일시멘트
# 넥센타이어
# 영풍
# 미래에셋생명
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 케이씨텍
# 씨아이에스
# 동양생명
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# SK오션플랜트
# 일진하이솔루스
# 경동나비엔
# 한세실업
# 제이알글로벌리츠
# 와이지엔터테인먼트
# 아시아나항공
# DS단석
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 롯데리츠
# 흥아해운
# DN오토모티브
# 한화엔진
# 아이에스동서
# 보령
# 현대바이오
# 씨앤씨인터내셔널
# 엔젤로보틱스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# TKG휴켐스
# 대신증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 롯데관광개발
# 세아베스틸지주
# 제룡전기
# NHN
# 제이오
# LG전자우
# 명신산업
# 한화투자증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 태광산업
# 녹십자홀딩스
# 브이티
# 필옵틱스
# 실리콘투
# OCI
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 후성
# 삼성화재우
# 신풍제약
# JW중외제약
# 시노펙스
# 동아쏘시오홀딩스
# 쏘카
# 현대홈쇼핑
# 엠로
# 진에어
# 미원에스씨
# 성우하이텍
# 현대지에프홀딩스
# 바이오니아
# 덕산테코피아
# 대상
# KG스틸
# CJ CGV
# 드림텍
# 우리기술투자
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 제이시스메디칼
# DI동일
# SK이터닉스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 디어유
# 동원F&B
# 스마트솔루션즈
# SNT모티브
# 안랩
# KCC글라스
# 커넥트웨이브
# 현대힘스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에스피지
# 한국단자
# 인텔리안테크
# 신세계인터내셔날
# 쿠쿠홀딩스
# PI첨단소재
# 케이카
# 애경케미칼
# 자람테크놀로지
# NICE평가정보
# 지씨셀
# 신영증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 케이엠더블유
# 비에이치
# 에이직랜드
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에코앤드림
# 대한해운
# 삼양홀딩스
# 이엠텍
# 필에너지
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 동아에스티
# 오픈엣지테크놀로지
# 비올
# 윤성에프앤씨
# 유니드
# 빙그레
# F&F홀딩스
# 지아이이노베이션
# 티웨이항공
# 와이아이케이
# SNT다이내믹스
# LS에코에너지
# 아난티
# 신한알파리츠
# 네오셈
# 교보증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한국카본
# 데브시스터즈
# 동국제강
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 아이센스
# 지노믹트리
# 보로노이
# 네이처셀
# 자화전자
# 에스티아이
# 제우스
# 롯데정보통신
# 에이디테크놀로지
# 칩스앤미디어
# 클리오
# LX홀딩스
# 유안타증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 펩트론
# 유티아이
# 삼양사
# 에프에스티
# 프레스티지바이오파마
# 큐렉소
# 고려제강
# 아세아
# 미래에셋증권2우B
# 컴투스
# 미래나노텍
# 한화손해보험
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# HDC
# SPC삼립
# 쿠쿠홈시스
# 한글과컴퓨터
# 엘브이엠씨홀딩스
# 프로텍
# 서연이화
# 신성이엔지
# 신라젠
# 하나기술
# 툴젠
# 강원에너지
# 에이프로젠
# 엘앤씨바이오
# 애경산업
# 원익머트리얼즈
# 쎄트렉아이
# 탑머티리얼
# 다우데이타
# SBS
# 티앤엘
# 셀바스AI
# 젬백스
# 다원시스
# 신흥에스이씨
# 바텍
# E1
# 네오위즈
# 서부T&D
# NICE
# 동국산업
# LF
# 인텍플러스
# 케이아이엔엑스
# 엠씨넥스
# 한섬
# 티이엠씨
# 신영증권우
# 풀무원
# 아미코젠
# 코람코라이프인프라리츠
# 유바이오로직스
# 부광약품
# 화승엔터프라이즈
# 한국철강
# GST
# 디아이
# 세아홀딩스
# KB스타리츠
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 일동제약
# 소룩스
# 한국비엔씨
# 코리아써키트
# 월덱스
# 지역난방공사
# 박셀바이오
# 퍼시스
# 바이오노트
# RFHIC
# 뷰노
# 바이넥스
# 풍산홀딩스
# 현대퓨처넷
# 유진투자증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 위지윅스튜디오
# 퀄리타스반도체
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 큐로셀
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# HB솔루션
# 현대그린푸드
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 네패스
# 아이패밀리에스씨
# 카페24
# 비츠로셀
# 예스티
# 미코
# 삼현
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 티에프이
# 텔레칩스
# 아모레퍼시픽우
# 아세아제지
# 맵스리얼티1
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 네패스아크
# 세진중공업
# 삼성SDI우
# 켐트로닉스
# 삼성FN리츠
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 중앙첨단소재
# 바이오플러스
# 동운아나텍
# 제주은행
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한솔아이원스
# 위메이드맥스
# 엘오티베큠
# 아세아시멘트
# 태웅
# 코스메카코리아
# 신도리코
# SNT홀딩스
# 세아제강
# 한국기업평가
# 인바디
# 아이엠비디엑스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# KG케미칼
# 한국자산신탁
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 제이브이엠
# 대신증권우
# 선익시스템
# 삼화콘덴서
# 유나이티드제약
# 티로보틱스
# 광동제약
# 한일홀딩스
# 뉴로메카
# 남양유업
# 영진약품
# 삼천리
# LS네트웍스
# 한화리츠
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# HLB이노베이션
# 샘씨엔에스
# STX중공업
# 지오릿에너지
# 동성화인텍
# AP시스템
# 이엔에프테크놀로지
# KH바텍
# 삼부토건
# KISCO홀딩스
# CJ4우(전환)
# 화신
# 메드팩토
# 남해화학
# 쏠리드
# 현대무벡스
# LG생활건강우
# 신성에스티
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 이아이디
# 에이피티씨
# LX하우시스
# BGF
# 글로벌텍스프리
# LB세미콘
# 큐리옥스바이오시스템즈
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 디오
# 백광산업
# 세경하이테크
# 큐알티
# HB테크놀러지
# 인터플렉스
# 한양디지텍
# 현대차3우B
# 에스피소프트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 휴메딕스
# 디아이티
# 수산인더스트리
# 파미셀
# 국도화학
# 코엔텍
# 유진로봇
# 한양이엔지
# 한진
# HL홀딩스
# 한화3우B
# 석경에이티
# 조광피혁
# 제넥신
# 하이록코리아
# 대원강업
# 한국쉘석유
# 태광
# 아이쓰리시스템
# 바디텍메드
# 엑시콘
# 에스에이엠티
# 인터로조
# 스틱인베스트먼트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한국정보통신
# 알루코
# 코아스템켐온
# 송원산업
# 대상홀딩스
# 하이비젼시스템
# SGC에너지
# 감성코퍼레이션
# 성광벤드
# 케이씨
# 파인엠텍
# 하이드로리튬
# 대동
# HLB바이오스텝
# 삼목에스폼
# 대원제약
# 모트렉스
# 아주IB투자
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# KG ETS
# 하림
# 삼표시멘트
# 에어부산
# 유니테스트
# KG이니시스
# 로보티즈
# 오로스테크놀로지
# 폴라리스오피스
# 덕산하이메탈
# 서희건설
# 에이프릴바이오
# 와이씨켐
# 인선이엔티
# 한국콜마홀딩스
# 이리츠코크렙
# 로보스타
# 미래에셋벤처투자
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 솔트룩스
# 마녀공장
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 현대비앤지스틸
# 원익홀딩스
# 파워로직스
# 대한제강
# 농심홀딩스
# 삼익THK
# 사조대림
# 톱텍
# 미래반도체
# DB
# 상아프론테크
# CMG제약
# 어보브반도체
# 코미팜
# 한농화성
# 펌텍코리아
# 디앤씨미디어
# 종근당홀딩스
# 모두투어
# 코난테크놀로지
# BYC
# 젬백스링크
# 코나아이
# SIMPAC
# 티엘비
# STX엔진
# 디엔에프
# 락앤락
# 이월드
# 갤럭시아머니트리
# 에이스침대
# 지누스
# CJ프레시웨이
# 넵튠
# 비즈니스온
# 국전약품
# 서울가스
# 컨텍
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 가비아
# 우진엔텍
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 새로닉스
# 한일현대시멘트
# 에코아이
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# HLB글로벌
# 이스트소프트
# SK증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대한제당
# 비에이치아이
# 앱클론
# 비씨엔씨
# 싸이토젠
# 아이마켓코리아
# 휴온스글로벌
# 디이엔티
# 유니셈
# 엠케이전자
# 이수화학
# 현대차증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 삼진제약
# 유진기업
# HD현대에너지솔루션
# 삼양패키징
# 나노팀
# 뷰웍스
# 유일로보틱스
# CR홀딩스
# KEC
# 백산
# 일성신약
# 코오롱플라스틱
# LS마린솔루션
# 프레스티지바이오로직스
# 한국금융지주우
# 토비스
# CG인바이츠
# 이연제약
# 코윈테크
# HJ중공업
# 콘텐트리중앙
# 포스코스틸리온
# 일양약품
# 다날
# 한화갤러리아
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 비나텍
# 슈어소프트테크
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 환인제약
# 잇츠한불
# 아나패스
# 두산우
# 모토닉
# 케이티알파
# 원익피앤이
# YG PLUS
# 바이오다인
# LG헬로비전
# 조일알미늄
# 에브리봇
# 신성통상
# 스카이라이프
# 휴스틸
# 서흥
# AP위성
# 한국토지신탁
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 코세스
# 대성에너지
# 웅진씽크빅
# 뉴파워프라즈마
# 흥국화재
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 비덴트
# 유비케어
# 알멕
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 도화엔지니어링
# 리튬포어스
# 케이엔솔
# 제테마
# 원준
# 코오롱생명과학
# 엑세스바이오
# 동국홀딩스
# 동화약품
# 해성산업
# 잉글우드랩
# STX
# 시너지이노베이션
# 레이
# 이베스트투자증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 휴마시스
# 부국증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 이트론
# 동원개발
# 셀리버리
# 오상헬스케어
# 새빗켐
# KPX홀딩스
# 미래컴퍼니
# 대명에너지
# 광주신세계
# 나스미디어
# 올릭스
# 에스티큐브
# 아바코
# 삼영무역
# 케이알엠
# 메디포스트
# 한솔제지
# 제일약품
# 인트론바이오
# 우리기술
# 남선알미늄
# JTC
# SNT에너지
# 와이솔
# 하나제약
# 그린리소스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 유비쿼스홀딩스
# 한전산업
# 에이팩트
# 이지스밸류리츠
# 그래디언트
# 나무가
# 큐라클
# 이수앱지스
# 신대양제지
# 케이엔알시스템
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 디앤디플랫폼리츠
# 가온전선
# 동성케미컬
# 쇼박스
# 에스와이
# 효성화학
# 퓨릿
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 씨에스베어링
# 진성티이씨
# 한국알콜
# 디알텍
# 인트로메딕
# 아이엠티
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 제이에스코퍼레이션
# 큐브엔터
# 예스코홀딩스
# TYM
# 포인트모바일
# 현대코퍼레이션
# 신한서부티엔디리츠
# 와이랩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 상신이디피
# 피에이치에이
# 서연
# 마크로젠
# GRT
# 롯데하이마트
# 삼화전기
# 씨씨에스
# JW홀딩스
# 한국파마
# 세방
# 동양
# 컴투스홀딩스
# 디와이피엔에프
# AJ네트웍스
# 엠아이텍
# 드림어스컴퍼니
# 넥센
# 더네이쳐홀딩스
# 경방
# 펨트론
# 자이언트스텝
# 대한제분
# 비츠로테크
# 대아티아이
# 대교
# 흥구석유
# 매커스
# 대보마그네틱
# HDC랩스
# 삼화페인트
# 삼성전기우
# BGF에코머티리얼즈
# GS글로벌
# KPX케미칼
# 퓨쳐켐
# 주성코퍼레이션
# 나이스정보통신
# 이노와이어리스
# 파로스아이바이오
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 인카금융서비스
# KX
# 대덕
# 일진홀딩스
# 엠에스오토텍
# 디아이씨
# 한국정보인증
# 아이디스
# 와이엠티
# 넥스트칩
# 사람인
# 코오롱모빌리티그룹
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 코오롱
# 이랜시스
# 멀티캠퍼스
# 하이트진로홀딩스
# 피에이치씨
# 이엔플러스
# 성신양회
# 헬릭스미스
# 한일사료
# 미스터블루
# 이랜텍
# 크레버스
# 휴림로봇
# 삼일제약
# 이지홀딩스
# 태림포장
# 동신건설
# 씨티씨바이오
# 코어라인소프트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 조선내화
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# SK디앤디
# 에이엘티
# 일신방직
# 좋은사람들
# 랩지노믹스
# 일진파워
# S-Oil우
# 테고사이언스
# 싸이맥스
# 파세코
# 한국공항
# 보광산업
# 교촌에프앤비
# 덱스터
# 삼영전자
# 네오팜
# 노바텍
# 한솔테크닉스
# NH투자증권우
# 우주일렉트로
# 신세계 I&C
# 노루페인트
# 크리스에프앤씨
# 쿠콘
# JW생명과학
# 경동인베스트
# 삼성출판사
# 사피엔반도체
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 알서포트
# 아바텍
# 만호제강
# 한국전자금융
# 경동제약
# 금호석유우
# 경농
# 코람코더원리츠
# 무림P&P
# KG모빌리언스
# 넥스틸
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 티움바이오
# AK홀딩스
# 한국캐피탈
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한국제지
# 진원생명과학
# 화승인더
# 에치에프알
# 켐트로스
# 에스비비테크
# 이구산업
# 상상인
# 사조산업
# NPC
# 와이지-원
# 대화제약
# 녹원씨엔아이
# 디지털대성
# 다올투자증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 타이거일렉
# 일진다이아
# 한세예스24홀딩스
# 한스바이오메드
# CJ제일제당 우
# 슈피겐코리아
# 코리아에프티
# 이녹스
# 한독
# 카나리아바이오
# KSS해운
# 딥노이드
# LG우
# 폰드그룹
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 네오위즈홀딩스
# 노바렉스
# 동국씨엠
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 영풍정밀
# 양지사
# 한울소재과학
# 한국석유
# 대양제지
# 조이시티
# 퓨런티어
# 하이딥
# 진양홀딩스
# 이화전기
# 키다리스튜디오
# 광무
# 유니켐
# 로체시스템즈
# 리파인
# 코아시아
# 지니뮤직
# 워트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 아시아나IDT
# 미원홀딩스
# 나이벡
# 삼성물산우B
# 아이텍
# 한미글로벌
# 에코플라스틱
# 동국S&C
# 동아지질
# 팜스토리
# 그린케미칼
# 제이엘케이
# YTN
# 강남제비스코
# 뉴프렉스
# 경보제약
# 아모그린텍
# 율호
# 우진
# 라온텍
# DB금융투자
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에이블씨엔씨
# 엔바이오니아
# LB루셈
# 헥토이노베이션
# 태경산업
# 윈스
# 드림시큐리티
# 모다이노칩
# 대성산업
# HLB파나진
# 금양그린파워
# 이닉스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 지투파워
# 엔케이맥스
# 에스엠벡셀
# 스마트레이더시스템
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 선진
# 티와이홀딩스
# 티앤알바이오팹
# 엑스게이트
# 케이엔제이
# 에이에스텍
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에이프로
# 코웰패션
# 엘앤케이바이오
# 유비쿼스
# 토니모리
# 디케이티
# 이에이트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 이브이첨단소재
# 서울옥션
# 아주스틸
# 삼기이브이
# 삼보판지
# 아비코전자
# 코오롱글로벌
# 제일파마홀딩스
# 대한약품
# 아이씨디
# 동구바이오제약
# 범한퓨얼셀
# 지앤비에스 에코
# 녹십자웰빙
# 와이더플래닛
# 헥토파이낸셜
# 유일에너테크
# 알에스오토메이션
# 도이치모터스
# 삼성제약
# 슈프리마
# 지오엘리먼트
# 금화피에스시
# 시그네틱스
# 에이치피오
# 동아타이어
# 팅크웨어
# 자이에스앤디
# SM C&C
# 위닉스
# 금강공업
# 퍼스텍
# 골프존뉴딘홀딩스
# 한신기계
# 금호건설
# 고려신용정보
# 엑셈
# 피엔에이치테크
# 청담글로벌
# 세종공업
# 디에스케이
# 보성파워텍
# DMS
# 동양이엔피
# 서울바이오시스
# 유니퀘스트
# 신테카바이오
# 티에스아이
# 아가방컴퍼니
# 제이스텍
# 야스
# 태경케미컬
# 밀리의서재
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 휴비츠
# 이크레더블
# 아스플로
# 네오이뮨텍
# 현대리바트
# 와이바이오로직스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 케이프
# 안트로젠
# APS
# 에스바이오메딕스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하이로닉
# 대영포장
# 페이퍼코리아
# 아남전자
# 비보존 제약
# 케이에스피
# 미원화학
# 애니플러스
# 대창단조
# 엔지켐생명과학
# 에이비프로바이오
# 스맥
# NH올원리츠
# 홈센타홀딩스
# 태경비케이
# 벽산
# 샌즈랩
# 풍국주정
# 해태제과식품
# 오킨스전자
# 우신시스템
# 퀀타피아
# 노루홀딩스
# MDS테크
# 브이원텍
# 대원전선
# 스피어파워
# 제이씨케미칼
# 삼양통상
# 한국무브넥스
# 경인양행
# 고스트스튜디오
# 한성크린텍
# 대성홀딩스
# 오리엔탈정공
# 라온피플
# 디와이
# 레이언스
# 대한화섬
# 한국주철관
# 아진산업
# 켄코아에어로스페이스
# 블루엠텍
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 더라미
# 중앙에너비스
# 고바이오랩
# 유수홀딩스
# 3S
# 덕양산업
# 제이아이테크
# 티케이케미칼
# 크리스탈신소재
# 폴라리스AI
# 디와이파워
# 신세계푸드
# 엔젯
# 무학
# 효성ITX
# 진흥기업
# 브랜드엑스코퍼레이션
# 삼지전자
# 리드코프
# 다산네트웍스
# 코닉오토메이션
# 한빛레이저
# 동성제약
# 와이투솔루션
# 라파스
# KTcs
# 서플러스글로벌
# 마음AI
# 성창기업지주
# 나인테크
# 덴티스
# 압타바이오
# CJ 바이오사이언스
# 에이스테크
# 엘티씨
# 샘표
# 대신증권2우B
# 인스코비
# 신라교역
# 아모레G3우(전환)
# 플리토
# 와이엠텍
# 인성정보
# 삼영
# 아이티센
# 빅텍
# 용평리조트
# 현대이지웰
# HDC현대EP
# 덕성
# 극동유화
# 덕우전자
# 세종텔레콤
# 브릿지바이오테라퓨틱스
# 심텍홀딩스
# CJ우
# 에이티넘인베스트
# 신흥
# DXVX
# 바이오솔루션
# 신스틸
# SBI인베스트먼트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 모베이스전자
# 우리바이오
# 엠플러스
# 오이솔루션
# 라온시큐어
# 미창석유
# 푸른저축은행
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 신일전자
# 아미노로직스
# 휴비스
# 사조동아원
# 현대바이오랜드
# 우리산업
# 셀바스헬스케어
# 대원미디어
# 유니슨
# 대창
# 테라젠이텍스
# 케이엔에스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한국경제TV
# 특수건설
# 한양증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 시스웍
# 초록뱀미디어
# 코렌텍
# 레드캡투어
# 씨앤지하이테크
# 신원
# 인피니트헬스케어
# 동인기연
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 풍원정밀
# 에스코넥
# 에이텍
# 메가스터디
# 솔본
# 금호에이치티
# 태웅로직스
# 차백신연구소
# 알에프텍
# NI스틸
# 강스템바이오텍
# 농우바이오
# 메디아나
# 케이엔더블유
# 인크로스
# 에이비온
# 대원산업
# SG
# 종근당바이오
# 지엔씨에너지
# 아이에이
# 이지바이오
# 이루다
# 엠투아이
# 트루윈
# 웹케시
# 미래에셋글로벌리츠
# 유화증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한컴라이프케어
# 케이피에스
# 에이프로젠바이오로직스
# 부방
# 수산중공업
# 디씨엠
# 와이엔텍
# 엔피
# 아센디오
# 위메이드플레이
# 베노티앤알
# 광전자
# 지놈앤컴퍼니
# 와이팜
# 이오플로우
# 샘표식품
# 아모센스
# 대양전기공업
# 서남
# 제노코
# 코텍
# 공구우먼
# 계룡건설
# 오션브릿지
# 제너셈
# 코츠테크놀로지
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 현대약품
# SBW생명과학
# 레뷰코퍼레이션
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 조선선재
# 케이옥션
# 세운메디칼
# 휴센텍
# 일월지엠엘
# KH 필룩스
# 비디아이
# 대정화금
# 모비스
# 링네트
# 한솔홀딩스
# 두올
# 탑엔지니어링
# KNN
# 인지컨트롤스
# 에스넷
# 유니트론텍
# 크라우드웍스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 씨싸이트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 화천기계
# SAMG엔터
# 엘컴텍
# 키이스트
# 포인트엔지니어링
# 그린플러스
# 트루엔
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 이노메트리
# 네온테크
# 코리아나
# 엠투엔
# 선광
# 예스24
# 지어소프트
# 현대에버다임
# 세아특수강
# 지아이텍
# 삼보모터스
# 큐리언트
# 마이크로디지탈
# 대한뉴팜
# 에스엠코어
# 청호ICT
# 디바이스이엔지
# 한국내화
# 제일전기공업
# 경동도시가스
# 이지케어텍
# 데이타솔루션
# 저스템
# 옵트론텍
# 동아화성
# 디알젬
# 삼익악기
# 황금에스티
# KCTC
# 동부건설
# 비엠티
# 하인크코리아
# 남화산업
# 한국화장품제조
# 오성첨단소재
# 우수AMS
# 에프엔에스테크
# 에스트래픽
# 현대공업
# 국제약품
# DRB동일
# 한국수출포장
# 지니언스
# 유아이엘
# 엔비티
# DSC인베스트먼트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 휴맥스
# 쎌바이오텍
# 센서뷰
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에스앤디
# 바이오에프디엔씨
# 아모텍
# 엑스페릭스
# 위더스제약
# 인화정공
# 이삭엔지니어링
# 인천도시가스
# 뉴온
# 이지스레지던스리츠
# 이엠코리아
# 이노시스
# 제로투세븐
# 매일홀딩스
# 광명전기
# 컴퍼니케이
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 동남합성
# 에스텍파마
# 라이온켐텍
# 메가터치
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대봉엘에스
# 팜스코
# 제이티
# 라온테크
# 유니온머티리얼
# 삼원강재
# 테이팩스
# 아진엑스텍
# 국보디자인
# 모나리자
# 포스뱅크
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 지에스이
# 엠게임
# 정상제이엘에스
# 아이디스홀딩스
# 캠시스
# 동일고무벨트
# 피엔티엠에스
# 다이나믹디자인
# 팸텍
# 티에스넥스젠
# SV인베스트먼트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 웨스트라이즈
# 알비더블유
# 노랑풍선
# 이큐셀
# 자이글
# 에스피시스템스
# 서원인텍
# 한국특강
# 에이스토리
# 우리손에프앤지
# 소니드
# 포바이포
# 한국화장품
# 블리츠웨이
# 화일약품
# 엔브이에이치코리아
# 우듬지팜
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# HS애드
# 엠벤처투자
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 빅솔론
# 동방
# 선바이오
# 가온그룹
# 다보링크
# 하이텍팜
# 맥스트
# 조흥
# SCI평가정보
# 태성
# 한선엔지니어링
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 메쎄이상
# 일동홀딩스
# 플래스크
# 세이브존I&C
# 동일산업
# 삼아제약
# 한라IMS
# 수젠텍
# 크라운제과
# 중앙백신
# 미래생명자원
# 성호전자
# 파이버프로
# 안국약품
# 대성창투
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# KIB플러그에너지
# SK이노베이션우
# 폴라리스세원
# 비아트론
# 텔코웨어
# 인포마크
# 세아메카닉스
# 꿈비
# 레이저옵텍
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에이테크솔루션
# 상보
# 휴니드
# 비트컴퓨터
# 액토즈소프트
# 제이엔케이히터
# KTis
# 와이어블
# 세코닉스
# 한송네오텍
# 제이엠티
# 베뉴지
# 팜젠사이언스
# 화성산업
# 화인써키트
# 앤디포스
# 손오공
# JW신약
# 에스퓨얼셀
# 참좋은여행
# 서호전기
# 옵투스제약
# 옵티팜
# 진로발효
# 디스플레이텍
# 한국컴퓨터
# LB인베스트먼트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 세보엠이씨
# 해성티피씨
# 국순당
# 오파스넷
# 메타바이오메드
# 지엘팜텍
# 현대코퍼레이션홀딩스
# 스톰테크
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 이라이콤
# 일승
# 선진뷰티사이언스
# 모델솔루션
# 씨티케이
# 와이엠씨
# 대동기어
# 버킷스튜디오
# 흥국에프엔비
# 삼양옵틱스
# KCC건설
# 피제이전자
# 신송홀딩스
# 링크제니시스
# 웅진
# 나우IB
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 정다운
# CJ씨푸드
# 바이젠셀
# 제노레이
# 코셈
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 애니젠
# 메카로
# 아이씨에이치
# 유틸렉스
# 로보로보
# 엠젠솔루션
# 유라테크
# 경남스틸
# 소마젠
# 한진중공업홀딩스
# 영화테크
# 센코
# 코스맥스엔비티
# 위지트
# 코스맥스비티아이
# 아톤
# 희림
# 인바이오젠
# 유니테크노
# 금강철강
# 러셀
# 나노엔텍
# 노을
# HRS
# 토마토시스템
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# CNT85
# 바이오톡스텍
# 한컴위드
# 스코넥
# 신신제약
# 티비씨
# 영풍제지
# 케이피에프
# 인벤티지랩
# 케이사인
# 나이스디앤비
# 대양금속
# 광림
# 오상자이엘
# 방림
# 홈캐스트
# 티사이언티픽
# 오리콤
# 엠에스씨
# 에스텍
# 알체라
# 씨앤투스
# SBI핀테크솔루션즈
# 본느
# 화승코퍼레이션
# 제이엔비
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에프앤가이드
# 오스테오닉
# 태영건설
# SG글로벌
# 파이오링크
# 무림페이퍼
# 래몽래인
# 오비고
# 레이저쎌
# 인팩
# 엔시스
# 에스엔유
# 대구백화점
# 아이진
# 텔콘RF제약
# 유니크
# 뉴트리
# 진양산업
# 위드텍
# 서한
# 제노포커스
# 크라운해태홀딩스
# 동아엘텍
# 오르비텍
# 큐에스아이
# 파멥신
# 아셈스
# 시공테크
# 에이플러스에셋
# 기신정기
# 핌스
# 액션스퀘어
# 제주맥주
# 녹십자엠에스
# 아이비김영
# 경창산업
# 모아데이타
# 대현
# 신일제약
# 동방아그로
# 피제이메탈
# NEW
# 깨끗한나라
# 자연과환경
# 한국선재
# 디케이락
# 리메드
# 엔젠바이오
# 브리지텍
# 티라유텍
# 디티앤씨알오
# 코센
# 파라텍
# 어스앤에어로스페이스
# 메디프론
# 성안
# 덕신하우징
# 에스와이스틸텍
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 알피바이오
# 미투온
# 제룡산업
# 이노뎁
# 동일금속
# KCI
# 남양유업우
# 콤텍시스템
# 신영와코루
# 피엔케이피부임상연구센타
# 유신
# 일신석재
# 제일연마
# KC코트렐
# 창해에탄올
# SG세계물산
# 유유제약
# 태평양물산
# 상신브레이크
# 에이텍모빌리티
# 인포뱅크
# 세원정공
# 케이씨에스
# 나래나노텍
# 테크엘
# 램테크놀러지
# 티쓰리
# 씨티알모빌리티
# 아스타
# 케어랩스
# 마이크로투나노
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 신세계건설
# 지엠비코리아
# 이엠넷
# 스톤브릿지벤처스
# 유니온
# 에이치엘사이언스
# 미래에셋맵스리츠
# 트윔
# 인지디스플레
# 삼호개발
# 프로이천
# 동양철관
# 프리엠스
# 비엘
# 세토피아
# 핑거
# 대한광통신
# 두산퓨얼셀1우
# 네오오토
# 모니터랩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 포시에스
# 레몬
# 이노시뮬레이션
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# TJ미디어
# KX하이텍
# 에코바이오
# 마이크로컨텍솔
# 나무기술
# 제이투케이바이오
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 서린바이오
# 태양금속
# 오픈베이스
# 사조오양
# 우림피티에스
# 플레이디
# 알리코제약
# 윈팩
# NH프라임리츠
# 샤페론
# 고려산업
# 삼현철강
# 케일럼
# 유성티엔에스
# 푸드나무
# 카이노스메드
# NPX
# 머큐리
# 모비데이즈
# 씨엔알리서치
# 코메론
# 인스웨이브시스템즈
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 바이오스마트
# 유진테크놀로지
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 모베이스
# SK우
# 팬엔터테인먼트
# 수산아이앤티
# 탑코미디어
# 플레이그램
# 제이씨현시스템
# SM Life Design
# 한국전자인증
# 동원금속
# 한신공영
# 줌인터넷
# FSN
# HB인베스트먼트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한싹
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 픽셀플러스
# RF머트리얼즈
# 에스메디
# SDN
# 상상인증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 바이브컴퍼니
# 모비릭스
# 아이큐어
# 웰크론
# 에스제이그룹
# 셀루메드
# 대림제지
# 엔투텍
# 마스턴프리미어리츠
# 내츄럴엔도텍
# 조광페인트
# 우양
# 코콤
# 아이엠
# CS홀딩스
# 키네마스터
# NE능률
# 아이톡시
# 삼기
# HL D&I
# 나라엠앤디
# CSA 코스믹
# 웨이브일렉트로
# 대호에이엘
# 대원화성
# 유한양행우
# 피코그램
# 대성하이텍
# 명문제약
# 액트로
# 버넥트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대창솔루션
# 고려제약
# 씨이랩
# 화승알앤에이
# 디지틀조선
# 혜인
# 한일단조
# EG
# 파수
# 아이에스이커머스
# 큐라티스
# DH오토웨어
# 에스씨디
# 보라티알
# 새론오토모티브
# 영림원소프트랩
# 하이소닉
# 미코바이오메드
# 구영테크
# 미래에셋드림스팩1호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 우리넷
# 마니커
# 대모
# 슈프리마에이치큐
# SH에너지화학
# 엔에프씨
# 린드먼아시아
# 기가레인
# 피엠티
# iMBC
# 엔케이
# 삼천리자전거
# 소프트센
# 써니전자
# 에이프로젠 H&G
# 에이치시티
# 우리산업홀딩스
# 수성웹툰
# 코디
# 지니틱스
# 모바일어플라이언스
# 보락
# 잉크테크
# 원티드랩
# 오로라
# 미래산업
# 영보화학
# 제놀루션
# 웨이버스
# 산돌
# 삼화전자
# 유성기업
# 인포바인
# 오토앤
# 쌍방울
# 비비씨
# 현우산업
# 유비벨록스
# 조광ILI
# 이글루
# 화천기공
# 케이피엠테크
# 에이디엠코리아
# 대동전자
# 에이루트
# 아이엘사이언스
# 윙입푸드
# 비아이매트릭스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에이치와이티씨
# 피에스텍
# 우리로
# 이니텍
# 오하임앤컴퍼니
# 원익
# 진양폴리
# 보해양조
# 삼화왕관
# 진양제약
# 자비스
# 삼성공조
# 힘스
# 인터지스
# 에코캡
# 동우팜투테이블
# 에코볼트
# 다스코
# 드림씨아이에스
# 흥국
# 네오크레마
# 코스텍시스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# KBG
# 아이퀘스트
# 삼화네트웍스
# 디에이피
# 프롬바이오
# 핸디소프트
# 오리엔트바이오
# NHN벅스
# 서진오토모티브
# GS우
# 진영
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대우부품
# 피씨엘
# 천일고속
# 호전실업
# 조비
# DSR
# 까뮤이앤씨
# 푸른기술
# CNH
# 티플랙스
# 두산2우B
# 아모레G우
# 인산가
# 서울식품
# 남성
# 코퍼스코리아
# 티에이치엔
# 일성건설
# 애머릿지
# 이글벳
# 라이트론
# 대륙제관
# 금비
# 지니너스
# 케이웨더
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 케이엘넷
# YBM넷
# 한솔로지스틱스
# 하츠
# 한일철강
# CBI
# 비상교육
# 제이스코홀딩스
# 뉴지랩파마
# 원바이오젠
# 팬젠
# 얼라인드
# 대원
# 에쎈테크
# 평화산업
# 캡스톤파트너스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 코데즈컴바인
# 오텍
# 쏘닉스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 유에스티
# 에프엔씨엔터
# 핑거스토리
# 퀀타매트릭스
# 한세엠케이
# 갤럭시아에스엠
# 엠아이큐브솔루션
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 클리노믹스
# 미디어젠
# 제일테크노스
# 삼정펄프
# 대림B&Co
# 효성오앤비
# 부국철강
# 와이즈버즈
# 케이비아이동국실업
# 피플바이오
# 씨유박스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 원익큐브
# 테라사이언스
# 한국팩키지
# 한국가구
# 나라셀라
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 부국증권우
# 태양
# 상신전자
# 이지트로닉스
# 한솔홈데코
# 핸즈코퍼레이션
# 서원
# 피델릭스
# 디에이테크놀로지
# 파인디앤씨
# 하이스틸
# 한독크린텍
# 에너토크
# 세원물산
# 우성
# 동국알앤에스
# 대주산업
# 플래티어
# 지더블유바이텍
# KH 건설
# 제일바이오
# 일지테크
# 남광토건
# 앱코
# 메가엠디
# 오픈놀
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# DSR제강
# 성도이엔지
# 코오롱인더우
# 신도기연
# 한국종합기술
# 씨아이테크
# 블루콤
# 이노테라피
# 일신바이오
# 남화토건
# 이건산업
# 코위버
# 큐로컴
# 부산산업
# 에이텀
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 클라우드에어
# 삼일씨엔에스
# 더블유에스아이
# 사조씨푸드
# 인지소프트
# 시디즈
# 비씨월드제약
# 신화인터텍
# 동양피스톤
# IHQ
# 그리티
# 윈텍
# 대유에이텍
# 문배철강
# 전진바이오팜
# 성보화학
# 브레인즈컴퍼니
# ITX-AI
# SK케미칼우
# 서암기계공업
# 진매트릭스
# 에이티세미콘
# 휴엠앤씨
# 파워넷
# TKG애강
# 고려시멘트
# 에스에이티
# 우리이앤엘
# EDGC
# 셀리드
# 아스트
# 스페코
# 티엘아이
# 오브젠
# STX그린로지스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# KC그린홀딩스
# 대유
# 라이콤
# 이상네트웍스
# SJM홀딩스
# 에스씨엠생명과학
# 한익스프레스
# 세명전기
# 아이즈비전
# 누보
# 큐캐피탈
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 현대에이치티
# 폴라리스우노
# 씨티프라퍼티
# 우진플라임
# 미래에셋증권우
# 한화솔루션우
# 스타리츠
# 피씨디렉트
# 모아텍
# 팜스빌
# 신풍제약우
# 씨유테크
# 아우딘퓨쳐스
# SG&G
# TPC
# 이미지스
# 옴니시스템
# 삼륭물산
# 바른손
# 진양화학
# 프리시젼바이오
# SJM
# 이화공영
# 세원이앤씨
# TS인베스트먼트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 화성밸브
# 에스디생명공학
# 일진디스플
# 디엔에이링크
# 화신정공
# 모나미
# 위세아이텍
# 이즈미디어
# 웰크론한텍
# 조아제약
# 인디에프
# 엘엠에스
# 우원개발
# 선도전기
# 코아시아씨엠
# 대명소노시즌
# KB오토시스
# 오디텍
# 에이엔피
# 오공
# 상상인인더스트리
# 재영솔루텍
# 플레이위드
# 엔피디
# 루멘스
# 엠브레인
# 체리부로
# 빅텐츠
# 롯데칠성우
# 승일
# 진시스템
# 엔에이치스팩20호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 스튜디오삼익
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 옵티시스
# 대창스틸
# 바이오인프라
# 한국테크놀로지
# 세림B&G
# 와이엠
# 이건홀딩스
# 아이윈
# 한주라이트메탈
# 시큐레터
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 현대건설우
# 한빛소프트
# KBI메탈
# 플라즈맵
# 쎄노텍
# 한네트
# 티웨이홀딩스
# 압타머사이언스
# 영흥
# 알에프세미
# DL이앤씨2우(전환)
# 티엔엔터테인먼트
# 유니드비티플러스
# 위즈코프
# 솔루스첨단소재1우
# 메이슨캐피탈
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에쓰씨엔지니어링
# 케이엠
# 한창제지
# 비투엔
# 휴림에이텍
# 아세아텍
# 쌍용정보통신
# 삼영엠텍
# 솔트웨어
# 썸에이지
# 휴맥스홀딩스
# SGC이테크건설
# 케이탑리츠
# 한일화학
# 한국맥널티
# 신진에스엠
# 드림인사이트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 마니커에프앤지
# 빛샘전자
# 파버나인
# 웰바이오텍
# 비스토스
# 엔텔스
# 이루온
# 원풍
# 아이디피
# 컬러레이
# 아이크래프트
# 이원컴포텍
# 배럴
# 에스에이티이엔지
# 유투바이오
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 토탈소프트
# DH오토리드
# 멕아이씨에스
# 상지카일룸
# 오리엔트정공
# 케이디켐
# 푸드웰
# 케이씨티
# 아이스크림에듀
# 메타랩스
# 신화콘텍
# 뷰티스킨
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 씨큐브
# 젠큐릭스
# 유니온커뮤니티
# 와이제이엠게임즈
# 계양전기
# 엔터파트너즈
# 네오펙트
# 동양파일
# 알로이스
# 파인디지털
# 바른손이앤에이
# 네오티스
# MH에탄올
# 네이블
# 누리플렉스
# 지엔코
# 코맥스
# 비트나인
# 삼성스팩8호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 쎄니트
# 앤씨앤
# 원림
# 싸이버원
# 영화금속
# 크린앤사이언스
# 아시아경제
# 에이에프더블류
# PN풍년
# 오에스피
# 영우디에스피
# 백금T&A
# 대한과학
# 유엔젤
# 리더스코스메틱
# 비플라이소프트
# 한국전자홀딩스
# 삼일기업공사
# 아이앤씨
# 팬스타엔터프라이즈
# 대림통상
# 경남제약
# 휴네시온
# 대호특수강
# 하이즈항공
# 뉴인텍
# 나노브릭
# 동일기연
# 서연탑메탈
# 서전기전
# 디지캡
# 평화홀딩스
# 포메탈
# 비피도
# 예림당
# 디티앤씨
# 대신정보통신
# 그린생명과학
# 시지트로닉스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한국유니온제약
# 한국큐빅
# 오스템
# 밸로프
# SK디스커버리우
# 메디콕스
# 시큐브
# DL우
# 디케이앤디
# SGA솔루션즈
# 케이씨피드
# BYC우
# 카스
# 국동
# 세우글로벌
# THE E&M
# 하나금융25호스팩
# 큐로홀딩스
# 디와이디
# 휴럼
# YW
# KH 전자
# 나노씨엠에스
# 정원엔시스
# 이씨에스
# 이화산업
# 이엠앤아이
# 국영지앤엠
# 스튜디오미르
# GH신소재
# 서울제약
# 포커스에이치엔에스
# 삼진
# 율촌
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 바이오로그디바이스
# 형지엘리트
# 한창산업
# 베셀
# 룽투코리아
# 이스트아시아홀딩스
# 체시스
# 대성미생물
# 모헨즈
# 무림SP
# 핀텔
# 신시웨이
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 넥스턴바이오
# 우리엔터프라이즈
# 참엔지니어링
# 한화투자증권우
# 세화피앤씨
# 비엘팜텍
# 화인베스틸
# 삼보산업
# 유화증권우
# 플랜티넷
# 셀바이오휴먼텍
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하이트론
# TBH글로벌
# 옵티코어
# 코이즈
# 에스엘에스바이오
# 부산주공
# 인콘
# DL이앤씨우
# 성우테크론
# WISCOM
# 동방선기
# 이노룰스
# KR모터스
# 대동스틸
# 대한방직
# 윈하이텍
# 알파홀딩스
# 아이컴포넌트
# 에스에너지
# 네오리진
# 신한제11호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 동일제강
# 원일특강
# 씨유메디칼
# 메디앙스
# 동양에스텍
# 우진아이엔에스
# 피앤씨테크
# 부스타
# 세중
# 풍강
# 해성옵틱스
# 파인텍
# 신라섬유
# 아이윈플러스
# 프로티아
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 아이티아이즈
# 엑서지21
# 라닉스
# 윌링스
# 시큐센
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 케이바이오
# 삼영이엔씨
# 경인전자
# 알엔투테크놀로지
# 유안타증권우
# DGP
# TS트릴리온
# 와토스코리아
# 리더스 기술투자
# 나노
# 삼성스팩7호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 판타지오
# ES큐브
# 신원종합개발
# 토박스코리아
# 엔시트론
# 범양건영
# 진바이오텍
# 기산텔레콤
# 바이온
# 드래곤플라이
# 전방
# 윌비스
# 호텔신라우
# MIT
# 소프트캠프
# 협진
# 코리아에셋투자증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 동양고속
# 삼진엘앤디
# 성창오토텍
# 모코엠시스
# 디젠스
# 제이에스티나
# 웰킵스하이텍
# 씨엑스아이
# 우진비앤지
# 한탑
# 성우전자
# 제이엠아이
# 파나케이아
# 미래아이앤지
# 베스파
# 프럼파스트
# 국보
# 캐리소프트
# 성문전자
# 이노인스트루먼트
# 비비안
# 벨로크
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한성기업
# 라이프시맨틱스
# 인바이오
# 딜리
# 태원물산
# 대교우B
# 듀오백
# SUN&L
# 솔고바이오
# 지란지교시큐리티
# 이스타코
# 대성파인텍
# 셀레믹스
# 아즈텍WB
# 세기상사
# 엔피케이
# 신풍
# 로지시스
# 서울리거
# 케스피온
# 대유플러스
# 디와이씨
# 골드앤에스
# 블레이드 Ent
# 아시아종묘
# 브이씨
# 넥스트아이
# 삼일
# 원풍물산
# 셀피글로벌
# 티피씨글로벌
# 에스폴리텍
# 주연테크
# 에넥스
# 서산
# 다산솔루에타
# 카프로
# 알톤스포츠
# 에스디시스템
# 에이치케이
# 엔에이치스팩29호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 동원수산
# 로스웰
# 제넨바이오
# 진도
# 알티캐스트
# 롯데지주우
# 캐스텍코리아
# 글로본
# 한국주강
# 까스텔바작
# 이노진
# 파루
# 패션플랫폼
# 스킨앤스킨
# 에스앤더블류
# 제이준코스메틱
# 엑사이엔씨
# S&K폴리텍
# 세방우
# 대동금속
# 이엘피
# 금호전기
# 인터엠
# 윙스풋
# 서울전자통신
# 에스티오
# 나노캠텍
# 신라에스지
# 국일신동
# 케이피티유
# 대한항공우
# 에스에스알
# 한국ANKOR유전
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 엠에프엠코리아
# 스카이문스테크놀로지
# 더코디
# 글로벌에스엠
# 투비소프트
# 위니아에이드
# 웹스
# 헝셩그룹
# 스튜디오산타클로스
# 에이치앤비디자인
# KB제27호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 애드바이오텍
# 한솔PNS
# 삼영에스앤씨
# 유비온
# 엔지스테크널러지
# 우정바이오
# 뉴보텍
# 세동
# 비츠로시스
# SGA
# 케이비제22호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 세니젠
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 이퓨쳐
# 지티지웰니스
# 제닉
# 인베니아
# 케이엠제약
# BF랩스
# 두산퓨얼셀2우B
# CS
# 한솔인티큐브
# 녹십자홀딩스2우
# 씨엔플러스
# 한국정보공학
# 육일씨엔에쓰
# 형지I&C
# 비케이홀딩스
# 한창
# 코스나인
# 한국패러랠
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 유진스팩8호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 와이오엠
# 에스유홀딩스
# 예선테크
# 세진티에스
# 세종메디칼
# 파인테크닉스
# 대상우
# 디모아
# 골든센츄리
# 에스엘에너지
# 삼성스팩9호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# SHD
# 신영스팩7호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 커머스마이너
# 위니아
# 디딤이앤에프
# 오가닉티코스메틱
# 한국정밀기계
# 넥센타이어1우B
# 엑스큐어
# 아이오케이
# 디지아이
# 비유테크놀러지
# 에프알텍
# LX하우시스우
# 광진실업
# 대덕전자1우
# 휴림네트웍스
# 스타플렉스
# 솔루스첨단소재2우B
# 코리아써우
# 엘디티
# 유안타제13호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 누리플랜
# 비케이탑스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대신밸런스제16호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 동일철강
# 하나금융24호스팩
# 엔에이치스팩30호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대한제당우
# 엔에이치스팩26호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대산F&B
# 유아이디
# 덕성우
# 올리패스
# 신한제9호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하이트진로2우B
# 에스아이리소스
# KD
# 삼양홀딩스우
# 파커스
# 엔에이치스팩27호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 케이비제21호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 노블엠앤비
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 신영스팩8호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하나금융21호스팩
# 교보12호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대신밸런스제15호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 피피아이
# 하나30호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 엔에이치스팩23호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 신한제8호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하나28호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한화우
# 대신밸런스제14호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# NPC우
# 대상홀딩스우
# 코아스
# 일정실업
# 코오롱모빌리티그룹우
# 유안타제15호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대신밸런스제17호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 코오롱우
# 에이리츠
# 한진칼우
# KB제26호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한국제11호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 미래에셋비전스팩1호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하나26호스팩
# LX홀딩스1우
# 하나금융22호스팩
# 태양금속우
# 대신밸런스제13호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에이디칩스
# 한화플러스제3호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 삼성스팩6호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 키움제8호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해성산업1우
# 미래에셋비전스팩3호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 유진스팩7호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 유안타제9호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 유안타제10호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# JW중외제약2우B
# 신영스팩9호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하나27호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 유유제약1우
# DB금융스팩11호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 장원테크
# 하나31호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하나29호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에스케이증권제9호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 상상인제3호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 코다코
# 유안타제11호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 넥센우
# IBKS제20호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 엔에이치스팩24호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# IBKS제22호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 미래에셋비전스팩2호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 아리온
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하이제7호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하이제8호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 상상인제4호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한화플러스제4호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 삼양사우
# IBKS제21호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# JW중외제약우
# 신영스팩10호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 유안타제12호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 코오롱글로벌우
# 한화갤러리아우
# 유안타제14호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# IBKS제23호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# KB제25호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# IBKS제24호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 교보14호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 교보13호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 성신양회우
# 한국제13호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한국제12호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대덕1우
# 유진스팩10호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 비엔케이제1호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에이치엠씨제6호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 신한제10호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대원전선우
# 에스케이증권제11호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 키움제7호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 비엔케이제2호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한화플러스제2호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 교보15호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에스케이증권제8호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# SK증권우
# 유진스팩9호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 크라운제과우
# 에스케이증권제10호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# THE MIDONG
# 노루홀딩스우
# 키움제6호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하나32호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 엔에이치스팩25호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 일양약품우
# 한양증권우
# 노루페인트우
# 티와이홀딩스우
# 동원시스템즈우
# 남선알미우
# 크라운해태홀딩스우
# 코리아써키트2우B
# 하이트진로홀딩스우
# 흥국화재우
# 금강공업우
# 동부건설우
# 깨끗한나라우
# 태영건설우
# 계양전기우
# CJ씨푸드1우
# 서울식품우
# 성문전자우
# 소프트센우
# 진흥기업우B
# 진흥기업2우B
# 대호특수강우
# 유유제약2우B
# 금호건설우
# 동양2우B
# 동양우

# %% [markdown]
# ### 4. 데이터 정제

# %%
data.drop_duplicates(inplace = True)
data.sort_values(by = ['기업', '연도'], inplace = True)

# %%
display(data.head())
# Out:
#           기업    연도               자산총계               부채총계             자본총계  \
# 6788      3S  2020     49,658,374,621     16,293,352,322   33,365,022,299
# 6787      3S  2021     54,614,752,349     18,068,427,911   36,546,324,438
# 6786      3S  2022     65,127,864,527     26,788,875,680   38,338,988,847
# 6789      3S  2023     67,635,499,845     21,680,745,544   45,954,754,301
# 4928  AJ네트웍스  2020  1,588,170,350,000  1,300,162,539,894  288,007,810,106
#
#                   매출액            영업이익           당기순이익
# 6788   22,592,015,218     467,181,073  -1,080,358,319
# 6787   23,477,908,383  -1,408,265,950     695,334,883
# 6786   27,110,628,415   1,452,134,065   1,171,369,995
# 6789   41,857,755,025   2,180,508,808   1,431,602,721
# 4928  871,956,093,147  21,089,140,851  -3,316,812,122

# %%
# 숫자로 모두 변환
def convert_str_to_float(value):
    if type(value) == float: # nan의 자료형은 float임
        return value
    elif value == '-': # -로 되어 있으면 0으로 변환
        return 0
    else:
        return float(value.replace(',', ''))

for ind in ind_list:
    data[ind] = data[ind].apply(convert_str_to_float)

# %%
display(data.head())
# Out:
#           기업    연도          자산총계          부채총계          자본총계           매출액  \
# 6788      3S  2020  4.965837e+10  1.629335e+10  3.336502e+10  2.259202e+10
# 6787      3S  2021  5.461475e+10  1.806843e+10  3.654632e+10  2.347791e+10
# 6786      3S  2022  6.512786e+10  2.678888e+10  3.833899e+10  2.711063e+10
# 6789      3S  2023  6.763550e+10  2.168075e+10  4.595475e+10  4.185776e+10
# 4928  AJ네트웍스  2020  1.588170e+12  1.300163e+12  2.880078e+11  8.719561e+11
#
#               영업이익         당기순이익
# 6788  4.671811e+08 -1.080358e+09
# 6787 -1.408266e+09  6.953349e+08
# 6786  1.452134e+09  1.171370e+09
# 6789  2.180509e+09  1.431603e+09
# 4928  2.108914e+10 -3.316812e+09

# %% [markdown]
# ### 5. 주요 지표 계산

# %% [markdown]
# #### 부채비율

# %%
data['부채비율'] = data['부채총계'] / data['자본총계'] * 100
display(data['부채비율'].head())
# Out:
# 6788     48.833632
# 6787     49.439795
# 6786     69.873715
# 6789     47.178460
# 4928    451.433084
# Name: 부채비율, dtype: float64

# %% [markdown]
# #### 매출액 증가율, 영업이익 증가율, 당기순이익 증가율

# %%
data['매출액증가율'] = (data['매출액'].diff() / data['매출액'].shift(1)) * 100
data.loc[data['연도'] == 2013, '매출액증가율'] = np.nan

# %%
data['영업이익증가율'] = (data['영업이익'].diff() / data['영업이익'].shift(1)) * 100
data.loc[data['연도'] == 2013, '영업이익증가율'] = np.nan

data['당기순이익증가율'] = (data['당기순이익'].diff() / data['당기순이익'].shift(1)) * 100
data.loc[data['연도'] == 2013, '당기순이익증가율'] = np.nan

# %%
data = data.replace({np.inf:np.nan, -np.inf: np.nan})

# %% [markdown]
# #### 매출액 상태, 영업이익 상태, 당기순이익 상태

# %%
# 상태를 나타내는 함수 정의
def add_state(data, col):
    data[col + "_상태"] = np.nan # 상태를 결측으로 초기화
    value = data[col].values
    cur_value = value[1:]
    pre_value = value[:-1]
    # 흑자지속
    cond1 = (cur_value > 0) & (pre_value > 0)
    cond1 = np.insert(cond1, 0, np.nan)
    # 적자지속
    cond2 = (cur_value <= 0) & (pre_value <= 0)
    cond2 = np.insert(cond2, 0, np.nan)
    # 흑자전환
    cond3 = (cur_value > 0) & (pre_value <= 0)
    cond3 = np.insert(cond3, 0, np.nan)
    # 적자전환
    cond4 = (cur_value <= 0) & (pre_value > 0)
    cond4 = np.insert(cond4, 0, np.nan)

    # 조건에 따른 변환
    data.loc[cond1, col + "_상태"] = "흑자지속"
    data.loc[cond2, col + "_상태"] = "적자지속"
    data.loc[cond3, col + "_상태"] = "흑자전환"
    data.loc[cond4, col + "_상태"] = "적자전환"

# %%
add_state(data, "매출액")
add_state(data, "영업이익")
add_state(data, "당기순이익")

# %% [markdown]
# #### ROA

# %%
data['ROA'] = (data['당기순이익'] / data['자산총계']) * 100

# %% [markdown]
# #### ROE

# %%
average_equity = data['자본총계'].rolling(2).mean() # 평균 자기 자본
data['ROE'] = (data['당기순이익'] / average_equity) * 100
data.loc[data['연도'] == 2013, 'ROE'] = np.nan

# %% [markdown]
# #### 데이터 저장

# %%
data.to_csv("./data/주요재무지표_수정.csv", index = False, encoding = "utf-8")
display(data)
# Out:
#            기업    연도          자산총계          부채총계          자본총계           매출액  \
# 6788       3S  2020  4.965837e+10  1.629335e+10  3.336502e+10  2.259202e+10
# 6787       3S  2021  5.461475e+10  1.806843e+10  3.654632e+10  2.347791e+10
# 6786       3S  2022  6.512786e+10  2.678888e+10  3.833899e+10  2.711063e+10
# 6789       3S  2023  6.763550e+10  2.168075e+10  4.595475e+10  4.185776e+10
# 4928   AJ네트웍스  2020  1.588170e+12  1.300163e+12  2.880078e+11  8.719561e+11
# ...       ...   ...           ...           ...           ...           ...
# 9117       희림  2023  1.935073e+11  1.202178e+11  7.328949e+10  2.286523e+11
# 10964      힘스  2020  9.086640e+10  1.312457e+10  7.774182e+10           NaN
# 10963      힘스  2021  8.430302e+10  1.038679e+10  7.391623e+10           NaN
# 10962      힘스  2022  7.952340e+10  1.758886e+10  6.193453e+10           NaN
# 10965      힘스  2023  9.559763e+10  2.706650e+10  6.853113e+10           NaN
#
#                영업이익         당기순이익        부채비율       매출액증가율     영업이익증가율  \
# 6788   4.671811e+08 -1.080358e+09   48.833632          NaN         NaN
# 6787  -1.408266e+09  6.953349e+08   49.439795     3.921267 -401.438999
# 6786   1.452134e+09  1.171370e+09   69.873715    15.472929 -203.115045
# 6789   2.180509e+09  1.431603e+09   47.178460    54.396108   50.158919
# 4928   2.108914e+10 -3.316812e+09  451.433084  1983.141087  867.166047
# ...             ...           ...         ...          ...         ...
# 9117   7.376355e+09  6.377486e+09  164.031484     3.431106  -27.162720
# 10964  2.496817e+10  1.720465e+10   16.882255          NaN  238.489349
# 10963 -4.371187e+09 -4.413924e+08   14.052104          NaN -117.507035
# 10962 -1.327548e+10 -8.645207e+09   28.399120          NaN  203.704340
# 10965  5.685407e+09  5.599495e+09   39.495187          NaN -142.826362
#
#           당기순이익증가율 매출액_상태 영업이익_상태 당기순이익_상태        ROA        ROE
# 6788           NaN   적자전환    적자전환     적자전환  -2.175581        NaN
# 6787   -164.361506   흑자지속    적자전환     흑자전환   1.273163   1.989190
# 6786     68.461273   흑자지속    흑자전환     흑자지속   1.798570   3.128437
# 6789     22.216100   흑자지속    흑자지속     흑자지속   2.116644   3.396700
# 4928   -331.685235   흑자지속    흑자지속     적자전환  -0.208845  -1.986338
# ...            ...    ...     ...      ...        ...        ...
# 9117    -10.696738   흑자지속    흑자지속     흑자지속   3.295734   9.023100
# 10964   169.771695    NaN    흑자지속     흑자지속  18.934010  22.782895
# 10963  -102.565541    NaN    적자전환     적자전환  -0.523578  -0.582089
# 10962  1858.621469    NaN    적자지속     적자지속 -10.871275 -12.727505
# 10965  -164.769937    NaN    흑자전환     흑자전환   5.857358   8.583860
#
# [10769 rows x 17 columns]

# %% [markdown]
# # 양정고등학교 HRD 메이커 퀀트 실습 4
# ## 주요 재무지표 수집 및 가공하기
# [인증키 신청](https://opendart.fss.or.kr/uss/umt/EgovMberInsertView.do)

# %% [markdown]
# ### 1. 초기 세팅

# %%
! mkdir data

# %%
! wget https://raw.githubusercontent.com/stockjeong/hrdquant/refs/heads/main/2025stock.csv # 샘플 데이터 받아오기
# Out:
# --2025-05-07 10:16:37--  https://raw.githubusercontent.com/stockjeong/hrdquant/refs/heads/main/2025stock.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 343911 (336K) [text/plain]
# Saving to: ‘2025stock.csv’
#
# 2025stock.csv       100%[===================>] 335.85K  --.-KB/s    in 0.06s
#
# 2025-05-07 10:16:37 (5.27 MB/s) - ‘2025stock.csv’ saved [343911/343911]

# %%
! pip install OpenDartReader -q

# %% [markdown]
# ### 2. 데이터 파싱 전략 수립

# %%
import OpenDartReader
my_api = "49526a379265e67332f8abb3ddc10ab9f6af07db"
dart = OpenDartReader(my_api)

# %%
import pandas as pd

stock_list = pd.read_csv(
    "./2025stock.csv",
    encoding="utf-8",
    sep="\t",
    usecols=["Name", "Code"],
    dtype=str)

# %%
report = dart.finstate("005380", 2024)
display(report[["fs_nm", "account_nm", "thstrm_amount", "frmtrm_amount", "bfefrmtrm_amount"]])
# Out:
#      fs_nm  account_nm        thstrm_amount        frmtrm_amount  \
# 0   연결재무제표        유동자산  115,764,287,000,000  101,724,717,000,000
# 1   연결재무제표       비유동자산  224,034,142,000,000  180,738,638,000,000
# 2   연결재무제표        자산총계  339,798,429,000,000  282,463,355,000,000
# 3   연결재무제표        유동부채   79,509,643,000,000   73,362,103,000,000
# 4   연결재무제표       비유동부채  140,012,853,000,000  107,291,812,000,000
# 5   연결재무제표        부채총계  219,522,496,000,000  180,653,915,000,000
# 6   연결재무제표         자본금    1,488,993,000,000    1,488,993,000,000
# 7   연결재무제표       이익잉여금   96,595,668,000,000   88,665,805,000,000
# 8   연결재무제표        자본총계  120,275,933,000,000  101,809,440,000,000
# 9   연결재무제표         매출액  175,231,153,000,000  162,663,579,000,000
# 10  연결재무제표        영업이익   14,239,592,000,000   15,126,901,000,000
# 11  연결재무제표  법인세차감전 순이익   17,781,436,000,000   17,618,662,000,000
# 12  연결재무제표       당기순이익   13,229,908,000,000   12,272,301,000,000
# 13  연결재무제표   당기순이익(손실)   13,229,908,000,000   12,272,301,000,000
# 14  연결재무제표       총포괄손익   18,254,753,000,000   12,428,841,000,000
# 15    재무제표        유동자산   25,885,813,000,000   21,797,281,000,000
# 16    재무제표       비유동자산   70,257,815,000,000   63,267,354,000,000
# 17    재무제표        자산총계   96,143,628,000,000   85,064,635,000,000
# 18    재무제표        유동부채   20,530,589,000,000   18,594,079,000,000
# 19    재무제표       비유동부채    6,390,021,000,000    5,683,387,000,000
# 20    재무제표        부채총계   26,920,610,000,000   24,277,466,000,000
# 21    재무제표         자본금    1,488,993,000,000    1,488,993,000,000
# 22    재무제표       이익잉여금   64,217,561,000,000   56,425,494,000,000
# 23    재무제표        자본총계   69,223,018,000,000   60,787,169,000,000
# 24    재무제표         매출액   79,060,777,000,000   78,033,758,000,000
# 25    재무제표        영업이익    6,599,372,000,000    6,670,971,000,000
# 26    재무제표  법인세차감전 순이익   15,283,857,000,000    9,675,202,000,000
# 27    재무제표       당기순이익   12,240,535,000,000    7,343,003,000,000
# 28    재무제표   당기순이익(손실)   12,240,535,000,000    7,343,003,000,000
# 29    재무제표       총포괄손익   11,984,469,000,000    7,120,747,000,000
#
#        bfefrmtrm_amount
# 0    96,389,273,000,000
# 1   159,353,189,000,000
# 2   255,742,462,000,000
# 3    74,236,472,000,000
# 4    90,609,445,000,000
# 5   164,845,917,000,000
# 6     1,488,993,000,000
# 7    79,953,601,000,000
# 8    90,896,545,000,000
# 9   142,151,469,000,000
# 10    9,824,928,000,000
# 11   11,181,471,000,000
# 12    7,983,614,000,000
# 13    7,983,614,000,000
# 14    9,034,476,000,000
# 15   23,819,313,000,000
# 16   59,593,036,000,000
# 17   83,412,349,000,000
# 18   21,443,574,000,000
# 19    6,212,960,000,000
# 20   27,656,534,000,000
# 21    1,488,993,000,000
# 22   52,028,878,000,000
# 23   55,755,815,000,000
# 24   65,308,350,000,000
# 25    2,828,569,000,000
# 26    4,175,475,000,000
# 27    3,701,958,000,000
# 28    3,701,958,000,000
# 29    3,950,212,000,000

# %% [markdown]
# ### 3. 데이터 파싱

# %% [markdown]
# #### 데이터 파싱 함수 작성

# %%
import numpy as np
import pandas as pd

def find_fins_ind_list(stock_code, stock_name, year, ind_list):
    try: # 데이터 가져오기
        report = None
        report = dart.finstate(stock_code, year)
    except:
        pass

    if report is None:  # 리포트가 없다면 (참고: 리포트가 없으면 None을 반환함)
        # 리포트가 없으면 당기, 전기, 전전기 값 모두 제거
        data = [[stock_name, year] + [np.nan] * len(ind_list)]
        data.append([stock_name, year - 1] + [np.nan] * len(ind_list))
        data.append([stock_name, year - 2] + [np.nan] * len(ind_list))

    else:
        report = report[report["account_nm"].isin(ind_list)]  # 관련 지표로 필터링
        if sum(report["fs_nm"] == "연결재무제표") > 0:
            # 연결재무제표 데이터가 있으면 연결재무제표를 사용
            report = report.loc[report["fs_nm"] == "연결재무제표"]
        else:
            # 연결재무제표 데이터가 없으면 일반재무제표를 사용
            report = report.loc[report["fs_nm"] == "재무제표"]
        data = []
        for y, c in zip([year, year - 1, year - 2],
                        ["thstrm_amount", "frmtrm_amount", "bfefrmtrm_amount"]):
            record = [stock_name, y]
            for ind in ind_list:
                # account_nm이 indic인 행의 c 컬럼 값을 가져옴
                if sum(report["account_nm"] == ind) > 0:
                    value = report.loc[report["account_nm"] == ind, c].iloc[0]
                else:
                    value = np.nan
                record.append(value)
            data.append(record)

    return pd.DataFrame(data, columns=["기업", "연도"] + ind_list)

# %%
ind_list = ['자산총계', '부채총계', '자본총계', '매출액', '영업이익', '당기순이익']
display(find_fins_ind_list("005930", "삼성전자", 2024, ind_list))
# Out:
#      기업    연도                 자산총계                 부채총계                 자본총계  \
# 0  삼성전자  2024  514,531,948,000,000  112,339,878,000,000  402,192,070,000,000
# 1  삼성전자  2023  455,905,980,000,000   92,228,115,000,000  363,677,865,000,000
# 2  삼성전자  2022  448,424,507,000,000   93,674,903,000,000  354,749,604,000,000
#
#                    매출액                영업이익               당기순이익
# 0  300,870,903,000,000  32,725,961,000,000  34,451,351,000,000
# 1  258,935,494,000,000   6,566,976,000,000  15,487,100,000,000
# 2  302,231,360,000,000  43,376,630,000,000  55,654,077,000,000

# %% [markdown]
# #### 데이터 수집

# %%
import time
data = pd.DataFrame() # 이 데이터프레임에 각각의 데이터를 추가할 예정
for code, name in stock_list[['Code', 'Name']].values:
    print(name)
    for year in [2023, 2024]:
        try:
            result = find_fins_ind_list(code, name, year, ind_list) # 재무지표 데이터
        except:
            pass

        data = pd.concat([data, result], axis = 0, ignore_index = True) # data에 부착
        time.sleep(0.5)
# Out:
# 삼성전자
# SK하이닉스
# LG에너지솔루션
# 삼성바이오로직스
# 현대차
# 한화에어로스페이스
# 삼성전자우
# 셀트리온
# 기아
# KB금융
# HD현대중공업
# NAVER
# 신한지주
# 한화오션
# 현대모비스
# 메리츠금융지주
# POSCO홀딩스
# 삼성물산
# 크래프톤
# 카카오
# 하나금융지주
# 삼성화재
# HMM
# 삼성생명
# 두산에너빌리티
# HD한국조선해양
# 한국전력
# LG화학
# 고려아연
# SK이노베이션
# KT&G
# 우리금융지주
# 현대로템
# SK텔레콤
# 삼성중공업
# KT
# 삼성SDI
# HD현대일렉트릭
# 기업은행
# LG전자
# SK스퀘어
# 카카오뱅크
# LG
# 포스코퓨처엠
# 하이브
# SK
# 유한양행
# 삼성에스디에스
# 포스코인터내셔널
# 삼성전기
# 현대글로비스
# 한국항공우주
# SK바이오팜
# 대한항공
# 한화시스템
# HD현대마린솔루션
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 삼양식품
# 한미반도체
# HLB
# LIG넥스원
# 아모레퍼시픽
# 에코프로
# DB손해보험
# S-Oil
# 코웨이
# 미래에셋증권
# HD현대
# 레인보우로보틱스
# 맥쿼리인프라
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# LS ELECTRIC
# 한진칼
# HD현대미포
# 현대차2우B
# LG유플러스
# LG씨엔에스
# LG생활건강
# 한국타이어앤테크놀로지
# 두산
# 오리온
# 삼성카드
# NH투자증권
# 효성중공업
# 현대건설
# 두산밥캣
# 삼성증권
# 한국금융지주
# LG디스플레이
# 카카오페이
# 한화솔루션
# 펩트론
# LS
# 삼성E&A
# 넷마블
# CJ제일제당
# 에코프로머티
# 코오롱티슈진
# SKC
# 포스코DX
# GS
# 한국가스공사
# JB금융지주
# 현대차우
# 강원랜드
# 한화
# CJ
# LG이노텍
# 에이비엘바이오
# BNK금융지주
# 삼천당제약
# 현대오토에버
# 두산로보틱스
# 키움증권
# 시프트업
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 현대제철
# 금호석유화학
# 한미약품
# SK바이오사이언스
# 엔씨소프트
# 한화비전
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 현대엘리베이터
# 에이피알
# 롯데케미칼
# 에스엠
# F&F
# 이마트
# 동서
# 농심
# 한전기술
# 에스원
# 서울보증보험
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한온시스템
# 롯데지주
# 한화생명
# SK가스
# 엘앤에프
# 네이처셀
# KCC
# 미스토홀딩스
# 한화엔진
# 대한전선
# 이수페타시스
# 보로노이
# 제일기획
# 셀트리온제약
# 영원무역
# 실리콘투
# 아시아나항공
# CJ대한통운
# 롯데쇼핑
# 한미사이언스
# 한전KPS
# 더존비즈온
# 현대해상
# 코스맥스
# BGF리테일
# DB하이텍
# 팬오션
# 한국콜마
# 동원산업
# 아모레G
# HL만도
# 신성델타테크
# 오뚜기
# 엔켐
# iM금융지주
# 루닛
# DL이앤씨
# HD현대인프라코어
# SK아이이테크놀로지
# 풍산
# 산일전기
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 코리안리
# 씨에스윈드
# 동진쎄미켐
# 대웅제약
# 호텔신라
# 신세계
# HDC현대산업개발
# 에스엘
# 한올바이오파마
# GS건설
# 파크시스템스
# 카페24
# 녹십자
# 솔브레인
# 케어젠
# 이수스페셜티케미컬
# 젬백스
# 한국앤컴퍼니
# 대우건설
# DN오토모티브
# 하이트진로
# SK리츠
# 브이티
# 씨젠
# 현대백화점
# 한솔케미칼
# 신영증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 금호타이어
# 영원무역홀딩스
# OCI홀딩스
# 코스모신소재
# 대주전자재료
# 메지온
# 메디톡스
# 더블유게임즈
# 한일시멘트
# SNT다이내믹스
# 오스코텍
# GS리테일
# 일진전기
# HD현대건설기계
# 대웅
# 현대위아
# 롯데에너지머티리얼즈
# 테크윙
# HD현대마린엔진
# 파라다이스
# HDC
# 롯데웰푸드
# 에스디바이오센서
# 종근당
# 서진시스템
# 오리온홀딩스
# 롯데렌탈
# ISC
# 올릭스
# 경동나비엔
# 롯데리츠
# 하이젠알앤엠
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 동양생명
# 디어유
# ESR켄달스퀘어리츠
# LX인터내셔널
# 롯데칠성
# 한국카본
# 세아제강지주
# 위메이드
# 지아이이노베이션
# 동원시스템즈
# 다우기술
# 세방전지
# 한샘
# LS에코에너지
# 빙그레
# 두산퓨얼셀
# KB발해인프라
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 고영
# SK네트웍스
# 프레스티지바이오파마
# 효성티앤씨
# 미래에셋생명
# 국일제지
# STX엔진
# 삼성화재우
# 엠앤씨솔루션
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 미원상사
# 레이크머티리얼즈
# 대신증권
# 쿠쿠홀딩스
# 유일로보틱스
# 롯데정밀화학
# DI동일
# 넥슨게임즈
# 효성
# SK오션플랜트
# 대상
# LX세미콘
# 덴티움
# 와이씨
# 코오롱인더
# LG화학우
# 현대지에프홀딩스
# 가온전선
# 제이앤티씨
# 하나투어
# 솔루엠
# 태광산업
# HS효성첨단소재
# 안랩
# SNT에너지
# 에스앤에스텍
# 동성화인텍
# 성광벤드
# 유진테크
# 미원에스씨
# NICE평가정보
# GKL
# HLB생명과학
# SK디스커버리
# 보령
# SNT모티브
# 피에스케이홀딩스
# 원텍
# 롯데관광개발
# NHN
# 하나마이크론
# CJ CGV
# 동원F&B
# 필옵틱스
# 교보증권
# 태영건설
# 이노션
# 대덕전자
# 한화투자증권
# LS머트리얼즈
# 한화리츠
# 신한알파리츠
# 펌텍코리아
# 영풍
# 비에이치아이
# 케이카
# 율촌화학
# 전진건설로봇
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# HLB테라퓨틱스
# 나노신소재
# TKG휴켐스
# 휴온스글로벌
# 한국단자
# 엠로
# 디앤디파마텍
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# KG모빌리티
# DL
# SK케미칼
# 동아쏘시오홀딩스
# 금양
# 녹십자홀딩스
# 차바이오텍
# 두산우
# HJ중공업
# 현대힘스
# 카프로
# 세아베스틸지주
# 태성
# HLB제약
# 파미셀
# 풀무원
# 미래에셋증권2우B
# 아난티
# LG전자우
# 지역난방공사
# 시노펙스
# 현대홈쇼핑
# 오름테라퓨틱
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 위메이드맥스
# KG스틸
# 티앤엘
# 아세아
# 대한유화
# 씨아이에스
# 태광
# 에스피지
# 코스모화학
# 유안타증권
# 유니드
# 우리기술투자
# SPC삼립
# 비츠로셀
# 아이에스동서
# 롯데손해보험
# 현대바이오
# 제주항공
# 솔루스첨단소재
# 한글과컴퓨터
# 제이알글로벌리츠
# 바이넥스
# 코나아이
# 세아제강
# 현대그린푸드
# LS마린솔루션
# TCC스틸
# SNT홀딩스
# JW중외제약
# OCI
# 코스메카코리아
# 삼양홀딩스
# 파두
# 네오위즈
# 넥센타이어
# SK이터닉스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대한해운
# KCC글라스
# 쿠쿠홈시스
# 퍼시스
# 제룡전기
# LX홀딩스
# 케이씨텍
# 가온칩스
# 쎄트렉아이
# 티에스이
# 삼양사
# 세진중공업
# 쏘카
# 대상홀딩스
# SFA반도체
# 로보티즈
# 엘앤씨바이오
# 데브시스터즈
# 클로봇
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 현대무벡스
# F&F홀딩스
# 바이오노트
# 일진하이솔루스
# 바이오플러스
# 한화손해보험
# 비올
# 한텍
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 삼현
# 고려제강
# 중앙첨단소재
# 덕산테코피아
# 후성
# PI첨단소재
# 진에어
# 에코앤드림
# 티웨이항공
# 남양유업
# DS단석
# 휴메딕스
# 화승엔터프라이즈
# 동국제강
# 한국쉘석유
# 다우데이타
# 아이센스
# 드림텍
# 제주반도체
# 성우하이텍
# 한일홀딩스
# 코엔텍
# 신라젠
# 스틱인베스트먼트
# 코람코라이프인프라리츠
# 동신건설
# LF
# 비에이치
# 한세실업
# 퓨쳐켐
# 바이오니아
# 동운아나텍
# 대신증권우
# 솔트룩스
# 동아에스티
# 에스티큐브
# 동화기업
# 엠씨넥스
# E1
# 인텔리안테크
# 더본코리아
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해성디에스
# 바이오다인
# 테스
# 유바이오로직스
# 넵튠
# 명신산업
# NICE
# 오리엔트정공
# GS피앤엘
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 삼성FN리츠
# 큐리옥스바이오시스템즈
# 아세아시멘트
# 한국기업평가
# 쏠리드
# 제우스
# 큐로셀
# 네오셈
# 에프에스티
# 신도리코
# 맵스리얼티1
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# CJ4우(전환)
# KB스타리츠
# 지누스
# 신풍제약
# 성일하이텍
# 서희건설
# 인카금융서비스
# 디아이
# RFHIC
# 대한제강
# 풍산홀딩스
# 흥아해운
# 이엔에프테크놀로지
# 바디텍메드
# 아모레퍼시픽우
# 아이쓰리시스템
# 인화정공
# 케이아이엔엑스
# 글로벌텍스프리
# 서부T&D
# 셀바스AI
# 넥스틸
# 한화3우B
# 영진약품
# 삼표시멘트
# 애경산업
# 아이패밀리에스씨
# 지엔씨에너지
# 삼천리
# 엔젤로보틱스
# CMG제약
# 세아홀딩스
# 코미팜
# 유티아이
# 지노믹트리
# 칩스앤미디어
# 사조대림
# 아스테라시스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에이직랜드
# 선익시스템
# 현대차증권
# 이아이디
# 넥스트바이오메디컬
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 제주은행
# 비보존 제약
# 코오롱생명과학
# 삼아알미늄
# 한전산업
# 큐렉소
# 감성코퍼레이션
# 원익홀딩스
# 하이록코리아
# 한섬
# 켐트로닉스
# 천보
# 한국금융지주우
# SBS
# 에이프릴바이오
# 조광피혁
# 현대차3우B
# 티엑스알로보틱스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 남해화학
# HL홀딩스
# BGF
# 지씨셀
# 애경케미칼
# 성신양회
# 클리오
# 유나이티드제약
# 신세계인터내셔날
# SGC에너지
# 우양에이치씨
# 프레스티지바이오로직스
# 피아이이
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 인터로조
# 스피어
# 코난테크놀로지
# YG PLUS
# 대한제당
# 큐리언트
# 하림
# 툴젠
# 갤럭시아머니트리
# 듀켐바이오
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 미코
# 포바이포
# 일동제약
# 씨앤씨인터내셔널
# 케이엠더블유
# 대화제약
# 현대퓨처넷
# 인바디
# 다원시스
# 우리기술
# GST
# 필에너지
# SAMG엔터
# 콜마홀딩스
# 에스티아이
# 씨메스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한일현대시멘트
# 바텍
# 아주IB투자
# 신대양제지
# 아세아제지
# 서연이화
# 농심홀딩스
# 기가비스
# 국도화학
# 코오롱
# 태웅
# 대원제약
# 한국철강
# 오픈엣지테크놀로지
# 제이오
# HD현대에너지솔루션
# 엘브이엠씨홀딩스
# 백산
# 삼목에스폼
# INVENI
# 신성통상
# 마녀공장
# 월덱스
# 메디포스트
# 휴스틸
# HLB이노베이션
# 뉴로메카
# KISCO홀딩스
# 한국정보통신
# 이리츠코크렙
# 광동제약
# 엣지파운드리
# 가비아
# 매일유업
# 아가방컴퍼니
# 미래에셋벤처투자
# 한양이엔지
# 대아티아이
# 온코닉테라퓨틱스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# CJ프레시웨이
# 에코아이
# 한국비엔씨
# 한국자산신탁
# 우주일렉트로
# 에이스침대
# 계룡건설
# 현대코퍼레이션
# 유진로봇
# 인탑스
# 신성이엔지
# 한진
# 부국증권
# 디앤디플랫폼리츠
# 송원산업
# 수산인더스트리
# 디오
# 뷰노
# 큐브엔터
# 노머스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# PKC
# 교촌에프앤비
# 삼일제약
# 에스에이엠티
# 롯데이노베이트
# 샘씨엔에스
# 대덕
# KG케미칼
# 부광약품
# 제테마
# 슈어소프트테크
# 신성에스티
# 유진기업
# 모토닉
# 동양철관
# 제이브이엠
# 엠아이텍
# 화신
# 대동
# 아이마켓코리아
# 잇츠한불
# 에코마케팅
# KG에코솔루션
# LX하우시스
# LS네트웍스
# 윤성에프앤씨
# JTC
# SIMPAC
# 비덴트
# 브이엠
# 화승인더
# 삼화콘덴서
# 폴라리스오피스
# 한국토지신탁
# AP시스템
# 예스티
# 나이벡
# DB증권
# 세경하이테크
# 석경에이티
# 디아이티
# 인트로메딕
# 시너지이노베이션
# LG생활건강우
# 삼영무역
# 인벤티지랩
# 에스앤디
# 서울가스
# NH투자증권우
# DB
# 대명에너지
# 유진투자증권
# 자화전자
# 토비스
# 이스트소프트
# 삼진제약
# 에스바이오메딕스
# 풍원정밀
# GRT
# KPX홀딩스
# 코오롱ENP
# 넥센
# 이트론
# 미래나노텍
# 그린케미칼
# 노바텍
# 오리엔탈정공
# 아나패스
# CR홀딩스
# 케이씨
# 인선이엔티
# 토모큐브
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 원익머트리얼즈
# 이지스밸류리츠
# KG이니시스
# 한농화성
# 뷰웍스
# 프로텍
# 셀비온
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 코리아써키트
# 자람테크놀로지
# 에이텍
# 에어부산
# 하이비젼시스템
# 에치에프알
# 일양약품
# 에이치브이엠
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한솔아이원스
# 파멥신
# 로보스타
# 쿠콘
# 쓰리빌리언
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 상아프론테크
# 에이프로젠
# 한국화장품제조
# 대원강업
# 종근당홀딩스
# 동방메디컬
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# HDC랩스
# 한화갤러리아
# JW홀딩스
# 대한제분
# 휴림로봇
# SK증권
# 동국홀딩스
# 킵스파마
# 와이씨켐
# 바이오솔루션
# 로체시스템즈
# 성우
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# DSC인베스트먼트
# 도화엔지니어링
# 파이버프로
# 광주신세계
# KH바텍
# 펨트론
# 리파인
# 디앤씨미디어
# SG
# 아스트
# 세방
# 포스코스틸리온
# 환인제약
# 푸른소나무
# 이엠텍
# 티로보틱스
# 한중엔시에스
# 흥국화재
# KPX케미칼
# 대성에너지
# GS글로벌
# 슈프리마
# 삼익THK
# 제이에스링크
# 잉글우드랩
# LS증권
# 멀티캠퍼스
# 아이씨티케이
# 토니모리
# 동원개발
# KSS해운
# 모트렉스
# 네오팜
# 압타바이오
# 삼양패키징
# 이지홀딩스
# 유니슨
# 다올투자증권
# 피에이치에이
# 이연제약
# 일성아이에스
# 스카이라이프
# 엑스게이트
# 안트로젠
# 에이디테크놀로지
# 아이스크림미디어
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 알루코
# 모두투어
# 해성산업
# 대진첨단소재
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 뉴파워프라즈마
# 디지털대성
# 삼영전자
# 무학
# 동성케미컬
# 모나용평
# 탑머티리얼
# 이월드
# 텔레칩스
# 와이즈넛
# 하나제약
# 대원전선
# 한국알콜
# 인스코비
# 해태제과식품
# 위지윅스튜디오
# TYM
# 유비케어
# 아바코
# 동국산업
# 제넥신
# 비츠로테크
# 코람코더원리츠
# 한솔제지
# 사람인
# 다날
# 쇼박스
# 이화전기
# 진성티이씨
# 이수앱지스
# 하이트진로홀딩스
# 유니테스트
# 동아지질
# 골프존홀딩스
# 에이비온
# 폰드그룹
# 일신방직
# 오리엔트바이오
# 나무가
# LB세미콘
# 소룩스
# 에어레인
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 박셀바이오
# 알서포트
# 케이티알파
# 케이프
# 노루홀딩스
# 제일일렉트릭
# 인터플렉스
# 오상헬스케어
# 에이유브랜즈
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 티에프이
# KZ정밀
# 와이지-원
# 시공테크
# 대교
# 경남스틸
# 엑세스바이오
# 무림P&P
# 이노스페이스
# 제일약품
# 현대비앤지스틸
# 강원에너지
# 파인엠텍
# 동국씨엠
# 현대사료
# 와이솔
# 퀄리타스반도체
# 디아이씨
# 폴라리스AI
# 신한서부티엔디리츠
# 아티스트유나이티드
# 신세계 I&C
# 나이스정보통신
# 삼양엔씨켐
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 아미코젠
# 나우IB
# AP위성
# 그래디언트
# 인크레더블버즈
# 웅진씽크빅
# 한국정보인증
# 덕산하이메탈
# 노바렉스
# 삼화전기
# 제이엘케이
# 이니텍
# 조일알미늄
# BGF에코머티리얼즈
# HB테크놀러지
# 에스와이
# 온코크로스
# 오로스테크놀로지
# 일진홀딩스
# 일성건설
# 젝시믹스
# 엑스페릭스
# 한국캐피탈
# LG헬로비전
# 마이크로디지탈
# 앱트뉴로사이언스
# 티엘비
# 이지바이오
# 대영포장
# 모다이노칩
# 보광산업
# 남선알미늄
# 일신석재
# 어보브반도체
# 아이디스
# 경방
# 모티브링크
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에스피소프트
# 휴마시스
# 경농
# JW생명과학
# 유니셈
# 유비쿼스홀딩스
# 한미글로벌
# 에스오에스랩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# CJ제일제당 우
# HB솔루션
# 마크로젠
# 경동제약
# 퍼스텍
# 매커스
# KX
# 에르코스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에이블씨엔씨
# 휴센텍
# 삼성출판사
# 이크레더블
# 미원화학
# 한국전자금융
# 유니켐
# 미창석유
# 엔케이맥스
# 동화약품
# 제닉
# 사조산업
# 에브리봇
# 딥노이드
# 네오위즈홀딩스
# 롯데하이마트
# 신원
# 선진뷰티사이언스
# 서연
# BYC
# 대양전기공업
# 일진다이아
# 씨티씨바이오
# 미원홀딩스
# 진양홀딩스
# 대동기어
# 탑런토탈솔루션
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 우진엔텍
# 나스미디어
# 웹케시
# 엘케이켐
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 진원생명과학
# AJ네트웍스
# 레드캡투어
# 파워로직스
# 케이에스피
# 에이럭스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에스와이스틸텍
# 미래반도체
# 삼성SDI우
# 드림시큐리티
# 노루페인트
# 켄코아에어로스페이스
# LG우
# 아티스트스튜디오
# 신흥에스이씨
# 애니플러스
# 씨어스테크놀로지
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 삼화페인트
# 엠케이전자
# 랩지노믹스
# 코오롱글로벌
# 이엔셀
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 콘텐트리중앙
# DH오토넥스
# 벽산
# 동국생명과학
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 덱스터
# 서흥
# 태양금속
# 금호석유화학우
# 한국주철관
# 삼성전기우
# KG모빌리언스
# 동구바이오제약
# 헥토이노베이션
# 삼지전자
# 앱클론
# 루미르
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한양증권
# SK디앤디
# 에이스테크
# 미래컴퍼니
# 한독
# 톱텍
# 흥구석유
# 한국파마
# 대동전자
# 한국제지
# CG인바이츠
# 조선내화
# 크레버스
# 동양이엔피
# 에이치이엠파마
# 꿈비
# 국전약품
# 네패스
# 유라테크
# NH올원리츠
# 대한약품
# 슈피겐코리아
# 디와이피엔에프
# 대신증권2우B
# 아이티센
# 강남제비스코
# 그리드위즈
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하나기술
# 비나텍
# 이지스레지던스리츠
# 방림
# 사조동아원
# 현대에버다임
# 엘오티베큠
# 엑셈
# 한라IMS
# 금화피에스시
# 태림포장
# 나인테크
# 우진
# 한국석유
# 코텍
# NPC
# 한세예스24홀딩스
# DMS
# 케이엔솔
# 아주스틸
# 넥써쓰
# HLB글로벌
# 오스테오닉
# 알멕
# HS효성
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 제로투세븐
# 더네이쳐홀딩스
# 광무
# 한양디지텍
# 현대리바트
# 인피니트헬스케어
# 디알텍
# 효성화학
# 지니언스
# 컨텍
# 신라교역
# 씨에스베어링
# 큐알티
# 와이엠티
# 한국공항
# 대원산업
# 코다코
# 블루엠텍
# 코윈테크
# LB인베스트먼트
# KEC
# 대한화섬
# 대창단조
# 서울바이오시스
# 한일사료
# 유수홀딩스
# 아톤
# 이구산업
# 지어소프트
# 윈스테크넷
# 대성산업
# 대봉엘에스
# 디케이티
# CJ우
# 페이퍼코리아
# 동양
# 태경산업
# 알에스오토메이션
# 티케이케미칼
# 인트론바이오
# 지투파워
# 엔바이오니아
# 특수건설
# 양지사
# 삼성제약
# 경동인베스트
# 이엠코리아
# 에이프로젠바이오로직스
# 삼양통상
# 고려신용정보
# 엠에스오토텍
# S-Oil우
# HLB바이오스텝
# 녹십자웰빙
# 보성파워텍
# 대성창투
# 원준
# 디씨엠
# 에이치엔에스하이텍
# 선진
# 토마토시스템
# 하이텍팜
# 스마트레이더시스템
# 티이엠씨
# 이노와이어리스
# 일승
# 신흥
# SM C&C
# 효성ITX
# 매일홀딩스
# 평화홀딩스
# 에스비비테크
# 금강공업
# 팜스토리
# YTN
# 태경케미컬
# 키다리스튜디오
# 부방
# 경인양행
# 켐트로스
# 한솔테크닉스
# 이랜시스
# 케이씨에스
# 강스템바이오텍
# 일진파워
# 케이엔제이
# 삼영
# 파세코
# 유화증권
# 금호에이치티
# 씨케이솔루션
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 제이스코홀딩스
# AK홀딩스
# 크리스탈신소재
# 도이치모터스
# 샌즈랩
# 경보제약
# 두산2우B
# 아이엠비디엑스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 사피엔반도체
# 코오롱모빌리티그룹
# 태경비케이
# 헥토파이낸셜
# 시스웍
# 오성첨단소재
# 아이텍
# CJ 바이오사이언스
# 와이팜
# 엑시콘
# 아이비김영
# 자이에스앤디
# 퓨런티어
# 엘앤케이바이오
# 동국S&C
# 삼보판지
# 한국경제TV
# 디와이파워
# 현대바이오랜드
# 포니링크
# 범한퓨얼셀
# 한빛레이저
# 네패스아크
# KH 필룩스
# 서호전기
# 유아이엘
# 에스엠벡셀
# 삼성물산우B
# 셀바스헬스케어
# 레뷰코퍼레이션
# 제일파마홀딩스
# 아바텍
# 네오이뮨텍
# 현대이지웰
# 이수화학
# 대원미디어
# 메가스터디
# 자이언트스텝
# 홈센타홀딩스
# 컴투스홀딩스
# 넥스트칩
# 에스텍
# 국보디자인
# 라파스
# 종근당바이오
# 테고사이언스
# 씨앤지하이테크
# 아시아나IDT
# 푸른저축은행
# 에코플라스틱
# 유니트론텍
# 코리아에프티
# 디이엔티
# 디엔에프
# 서울옥션
# 아모레G3우(전환)
# 티움바이오
# 동방
# 제노코
# 인텍플러스
# 이지케어텍
# 나노팀
# 샘표식품
# 드림어스컴퍼니
# 싸이맥스
# 율호
# 한진중공업홀딩스
# 핑거
# 유니퀘스트
# KIB플러그에너지
# 한국무브넥스
# 퓨처코어
# 신세계푸드
# 3S
# 위너스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 조선선재
# 메카로
# 쎌바이오텍
# 인성정보
# SJG세종
# 극동유화
# 초록뱀미디어
# 대창
# 이랜텍
# 농우바이오
# KTcs
# SBI인베스트먼트
# 유한양행우
# KT지니뮤직
# 신테카바이오
# 상지건설
# 우수AMS
# 티에스아이
# 바이오에프디엔씨
# M83
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 코세스
# 샘표
# 스튜디오미르
# 아모텍
# 데이원컴퍼니
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# APS
# 삼성공조
# 제룡산업
# 동남합성
# 한선엔지니어링
# 워트
# 레이저옵텍
# 금양그린파워
# SBI핀테크솔루션즈
# 휴니드
# 피노
# 레이
# 미스터블루
# 수산중공업
# KCTC
# 스맥
# 크라우드웍스
# 예스24
# 플리토
# 청호ICT
# 마음AI
# 플래스크
# 유라클
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 와이엔텍
# 오파스넷
# HS애드
# 우신시스템
# 빅텍
# HDC현대EP
# 에이에스텍
# 진로발효
# 삼익악기
# 세아특수강
# 메타바이오메드
# 제이아이테크
# CJ씨푸드
# 대성홀딩스
# 에이티넘인베스트
# 대호에이엘
# 코웰패션
# 그린리소스
# 엠디바이스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한국특강
# 웨이비스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에스엠씨지
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 아진산업
# 모나리자
# 헬릭스미스
# 와이바이오로직스
# 만호제강
# 풍국주정
# 코아스템켐온
# 화성밸브
# KNN
# 삐아
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 테라젠이텍스
# 한국화장품
# 모베이스전자
# 뉴프렉스
# 메디아나
# 상상인
# 지앤비에스 에코
# 엠에스씨
# 청담글로벌
# 컴퍼니케이
# 수산아이앤티
# 한국수출포장
# 신일전자
# 나노엔텍
# 현대약품
# LS티라유텍
# 메드팩토
# 아남전자
# 삼호개발
# 와이제이링크
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 휴먼테크놀로지
# 알에프텍
# 유비쿼스
# 티앤알바이오팹
# 조이시티
# 에스트래픽
# 태웅로직스
# 라온시큐어
# 금호건설
# 영보화학
# 크라운제과
# 우리바이오
# 한국피아이엠
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 오픈놀
# 홈캐스트
# MDS테크
# 하이딥
# 제닉스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# STX
# 에이치피오
# 레이언스
# 인천도시가스
# 다산네트웍스
# 솔본
# 한국선재
# 신신제약
# 티쓰리
# 미래에셋글로벌리츠
# 팅크웨어
# 선광
# 세운메디칼
# 제이에스코퍼레이션
# 남화산업
# 비씨엔씨
# 세보엠이씨
# 에스유앤피
# 동인기연
# 덕성
# 케이알엠
# 덴티스
# 깨끗한나라
# 디에스케이
# 진흥기업
# 삼아제약
# 밀리의서재
# 비아이매트릭스
# 코칩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 시지메드텍
# 싸이토젠
# 광전자
# 티와이홀딩스
# 와이엠텍
# 제이씨현시스템
# 리메드
# 원익피앤이
# 디와이
# 위닉스
# 코스맥스비티아이
# 라온테크
# 엠오티
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 엔지켐생명과학
# 경동도시가스
# 캔버스엔
# HLB제넥스
# 인포바인
# 리드코프
# 수성웹툰
# 사조씨푸드
# 고바이오랩
# 빅솔론
# 크리스에프앤씨
# 엑시온그룹
# 노을
# 네온테크
# 옵투스제약
# 엠게임
# 한송네오텍
# 대한뉴팜
# 제이엔케이글로벌
# 네오크레마
# 고스트스튜디오
# 와이랩
# 한솔홀딩스
# iMBC
# 베뉴지
# 동일산업
# 새로닉스
# HS화성
# 세명전기
# 버킷스튜디오
# 에이플러스에셋
# 트루엔
# 두올
# 현대코퍼레이션홀딩스
# 국제약품
# 하이드로리튬
# 우리손에프앤지
# 신스틸
# 형지엘리트
# 서원인텍
# 화천기계
# 동일고무벨트
# 동성제약
# 상신이디피
# 한국첨단소재
# 엘티씨
# 케이옥션
# 공구우먼
# 큐라클
# LK삼양
# 아이에스티이
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 크레오에스지
# NI스틸
# 이건홀딩스
# 코츠테크놀로지
# 한스바이오메드
# 삼기에너지솔루션즈
# 대주산업
# 한국내화
# 휴비스
# 아셈스
# 조흥
# 서플러스글로벌
# 지아이텍
# 하이로닉
# 스톰테크
# 삼원강재
# 중앙백신
# 한신기계
# 심플랫폼
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 로보로보
# SV인베스트먼트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# HL D&I
# DXVX
# 샤페론
# 하이스틸
# KCC건설
# 에이팩트
# 수젠텍
# 지놈앤컴퍼니
# 퓨릿
# 엠플러스
# 코리아나
# 세이브존I&C
# 부산산업
# 삼보모터스
# 에스엠코어
# 엠투아이
# 원티드랩
# 엔브이에이치코리아
# 비아트론
# 메쎄이상
# 신영와코루
# 아이진
# 아이디스홀딩스
# 차이커뮤니케이션
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 마이크로컨텍솔
# 대정화금
# 휴비츠
# 오이솔루션
# 제이씨케미칼
# 엘컴텍
# 에이텍모빌리티
# 인지컨트롤스
# 디와이덕양
# 현대공업
# 광림
# 노브랜드
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 새빗켐
# 무림페이퍼
# 디티앤씨알오
# 블랙야크아이앤씨
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 화일약품
# 라온피플
# 정상제이엘에스
# 인크로스
# 엔에스이엔엠
# 케이엔에스
# DRB동일
# 유니온
# KTis
# 민테크
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# TS인베스트먼트
# 유비벨록스
# 파로스아이바이오
# SG글로벌
# 야스
# 아모그린텍
# 정다운
# 황금에스티
# 지오엘리먼트
# 대현
# JW신약
# 팬스타엔터프라이즈
# 인터지스
# 서한
# 텔코웨어
# 크라운해태홀딩스
# 애니젠
# 안국약품
# 비트컴퓨터
# 이노메트리
# 대구백화점
# SCI평가정보
# 엔젯
# 창해에탄올
# 위더스제약
# 소노스퀘어
# 참좋은여행
# 한컴라이프케어
# 제일연마
# 에스넷
# 성창기업지주
# 신송홀딩스
# 씨티케이
# 동아화성
# 에스피시스템스
# 에이비프로바이오
# 화승코퍼레이션
# 자연과환경
# 이브이첨단소재
# 코메론
# 웅진
# 키이스트
# 동부건설
# 케이엔알시스템
# 에프앤가이드
# 오킨스전자
# CS홀딩스
# 우리산업
# 와이투솔루션
# NH프라임리츠
# HRS
# 링네트
# 린드먼아시아
# 위세아이텍
# HLB파나진
# 인스피언
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 미트박스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대보마그네틱
# 그린플러스
# 선바이오
# 라이온켐텍
# 유성티엔에스
# 피제이전자
# 라온텍
# 티비씨
# 오리콤
# 동방아그로
# 유니온머티리얼
# 영화테크
# 아이엠티
# 디와이디
# 한신공영
# 지에스이
# 세원정공
# 비엠티
# 바이오스마트
# 위츠
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 데이타솔루션
# 아미노로직스
# 재영솔루텍
# 남광토건
# 녹십자엠에스
# 세토피아
# 코렌텍
# 한컴위드
# 위지트
# 중앙에너비스
# 좋은사람들
# 에이스토리
# 씨씨에스
# 오픈베이스
# 제일엠앤에스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 센코
# 케이피에프
# 코아시아
# SK이노베이션우
# 국순당
# 엠투엔
# 유유제약
# 덕신이피씨
# AP헬스케어
# SKAI
# 호전실업
# 피앤에스미캐닉스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 사조오양
# 디케이락
# 아이엘사이언스
# 알엔투테크놀로지
# 삼부토건
# NPX
# 에프엔에스테크
# 타이거일렉
# 스톤브릿지벤처스
# 진양제약
# 티플랙스
# 이엘씨
# 웨이브일렉트로
# 평화산업
# 쓰리에이로직스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 지엘팜텍
# CBI
# 미래생명자원
# 폴라리스AI파마
# 다보링크
# 콤텍시스템
# 미래에셋드림스팩1호
# 에코바이오
# 디바이스이엔지
# 모비스
# 아이에이
# 세코닉스
# 아이씨디
# 신일제약
# 유니크
# 희림
# 금강철강
# 성안머티리얼스
# 윙입푸드
# 제노레이
# 차백신연구소
# 위메이드플레이
# 남양유업우
# 이닉스
# 코스맥스엔비티
# 강동씨앤엘
# 블리츠웨이스튜디오
# 엔시스
# 피제이메탈
# 팜스코
# 옵티팜
# 우듬지팜
# KS인더스트리
# 한울소재과학
# 대원
# 엔피
# 노랑풍선
# 모델솔루션
# 인디에프
# 한국컴퓨터
# 피에스텍
# 지엠비코리아
# 셀리드
# 팜젠사이언스
# 한울반도체
# 라메디텍
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 액토즈소프트
# 더즌
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 삼화전자
# 큐에스아이
# 위드텍
# 레몬
# 진시스템
# 유니테크노
# 써니전자
# 한켐
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 씨아이테크
# 한일단조
# 에이엘티
# 아이큐어
# 흥국에프엔비
# 코어라인소프트
# 세원물산
# 보라티알
# 유엔젤
# 위즈코프
# 제이스텍
# 현대ADM
# 고려산업
# 브릿지바이오테라퓨틱스
# 코콤
# 삼화왕관
# 토탈소프트
# 팬젠
# 대양금속
# 라이콤
# SDN
# 조광페인트
# 알비더블유
# 슈프리마에이치큐
# 인바이오젠
# 비상교육
# 모베이스
# 하츠
# 우리넷
# 메가터치
# 나이스디앤비
# 잉크테크
# 퀀타매트릭스
# 금호전기
# 삼양케이씨아이
# 까뮤이앤씨
# 소마젠
# RF시스템즈
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# YBM넷
# 에이프로
# 해성에어로보틱스
# 동일금속
# SM Life Design
# TP
# 진양산업
# 코닉오토메이션
# 갤럭시아에스엠
# 쌍방울
# 사이냅소프트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 엑스플러스
# 화인써키트
# 삼현철강
# 비트맥스
# 티디에스팜
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 조광ILI
# 플레이디
# 아진엑스텍
# 폴라리스세원
# 상보
# 아크솔루션스
# 티웨이홀딩스
# 테라사이언스
# 에스씨디
# 기신정기
# 일동홀딩스
# 덕우전자
# 이녹스
# 포인트엔지니어링
# 브이원텍
# 에코볼트
# 에이치시티
# 드림씨아이에스
# 알리코제약
# 이스타코
# 보해양조
# 네오오토
# 유신
# 한솔홈데코
# 아이지넷
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 신한글로벌액티브리츠
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# SCL사이언스
# 서남
# 포스뱅크
# 케이엔더블유
# 알체라
# 엔케이
# 우림피티에스
# 원익
# 하스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 옵티코어
# 한국전자인증
# 탑엔지니어링
# 대모
# 한국종합기술
# 아모센스
# 대림바스
# 와이어블
# 미래에셋증권우
# 오로라
# 서린바이오
# 삼영엠텍
# 엔지스테크널러지
# TJ미디어
# 인스웨이브시스템즈
# STX그린로지스
# 세원이앤씨
# 미래에셋맵스리츠
# 디지틀조선
# SG세계물산
# 동원금속
# KBI메탈
# 벡트
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 캐리
# 씨앤투스
# 보락
# 바이젠셀
# 에이치엘사이언스
# SK우
# 케이사인
# 제이투케이바이오
# 한국가구
# 오르비텍
# 삼정펄프
# GS우
# 스코넥
# 이건산업
# 이렘
# 혜인
# 옴니시스템
# 브리지텍
# 피엔케이피부임상연구센타
# 성호전자
# 캐리소프트
# 화천기공
# 테이팩스
# 아비코전자
# IHQ
# 와이엠씨
# 웨이버스
# 푸른기술
# 아스플로
# 흥국
# 제너셈
# DSR
# 주성코퍼레이션
# 구영테크
# 시디즈
# 코데즈컴바인
# 경창산업
# 팬엔터테인먼트
# 부국증권우
# 성도이엔지
# 링크제니시스
# 한국팩키지
# 프리엠스
# 한국비티비
# 아스타
# 심텍홀딩스
# 윈팩
# 케이엘넷
# 대한광통신
# 상신브레이크
# 유일에너테크
# 베노티앤알
# 현대에이치티
# 대성하이텍
# 모바일어플라이언스
# 케어랩스
# 메가엠디
# 바이브컴퍼니
# 오상자이엘
# 조비
# 새론오토모티브
# 이스트에이드
# 광명전기
# 서울식품
# 내츄럴엔도텍
# 프로이천
# 형지I&C
# 한솔로지스틱스
# 디알젬
# KH 건설
# 이삭엔지니어링
# 제일바이오
# 포시에스
# 셀로맥스사이언스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 티사이언티픽
# 서울리거
# 시그네틱스
# 동양피스톤
# 대륙제관
# 아이스크림에듀
# 화승알앤에이
# 한성크린텍
# 형지글로벌
# 에이테크솔루션
# 이글루
# 플랜티넷
# 다스코
# 피플바이오
# 대림제지
# 예림당
# 씨유테크
# 씨엔알리서치
# 나노실리칸첨단소재
# 삼천리자전거
# 서원
# 프롬바이오
# 블루콤
# 피엔에이치테크
# 에스퓨얼셀
# 아이빔테크놀로지
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 원익큐브
# 픽셀플러스
# 카티스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 인포뱅크
# DGI
# 넥스트아이
# 아모레G우
# 에이치엠넥스
# 세아메카닉스
# 엠젠솔루션
# 한싹
# 윌비스
# 산돌
# 더라미
# 케이비아이동국실업
# 웰크론
# 에너토크
# 셀바이오휴먼텍
# EDGC
# 딥마인드
# 액트로
# 트윔
# 미투온
# 디에이피
# 인지디스플레
# 나라엠앤디
# 파수
# 에쎈테크
# 대유
# 대창솔루션
# 에이루트
# 아이티아이즈
# CSA 코스믹
# 삼륭물산
# 파라텍
# 아이디피
# 셀루메드
# 우원개발
# 인팩
# 프럼파스트
# HB인베스트먼트
# 천일고속
# 유틸렉스
# NEW
# DL이앤씨2우(전환)
# 두산퓨얼셀1우
# 태양
# EG
# 금비
# 제일테크노스
# 모비데이즈
# 오비고
# 휴맥스
# 에스에이티이엔지
# 이엠넷
# 이글벳
# 명문제약
# 효성오앤비
# 에스디생명공학
# 코디
# 마니커에프앤지
# 엘엠에스
# 마니커
# 삼화네트웍스
# 일월지엠엘
# 디티씨
# 에스코넥
# 메타케어
# 아이씨에이치
# 선도전기
# 쎄니트
# 삼일씨엔에스
# 지더블유바이텍
# 가온그룹
# 현우산업
# 그리티
# 현대건설우
# 카스
# 램테크놀러지
# 싸이버원
# SG&G
# 협진
# 아이티센엔텍
# 범양건영
# DSR제강
# 엔비티
# 미디어젠
# 영풍제지
# 나무기술
# 알파칩스
# 동아엘텍
# 세종텔레콤
# 고려제약
# 머큐리
# 모니터랩
# 티이엠씨씨엔에스
# 저스템
# 애머릿지
# 한일철강
# 코위버
# 코오롱인더우
# 시큐레터
# 더블유에스아이
# 파인디앤씨
# 핸디소프트
# 티에이치엔
# 우리로
# 러셀
# 컬러레이
# 테크엘
# 한화솔루션우
# 경남제약
# 이노뎁
# 이상네트웍스
# 센서뷰
# 이오플로우
# 인지소프트
# 캠시스
# 알에프세미
# 메이슨캐피탈
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 씨이랩
# 동방선기
# 부국철강
# 화신정공
# 에스지헬스케어
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# CNT85
# 일지테크
# 문배철강
# 모헨즈
# 닷밀
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 파인메딕스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 옵티시스
# 우양
# 비투엔
# SH에너지화학
# 케이이엠텍
# 씨피시스템
# SB성보
# 유니드비티플러스
# 대동스틸
# 모아라이프플러스
# KX하이텍
# 핑거스토리
# 와이엠
# 코스텍시스
# 오토앤
# 에프엔씨엔터
# 디젠스
# 에넥스
# 다원넥스뷰
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# SGC E&C
# 푸드웰
# 파이오링크
# 한독크린텍
# 아진전자부품
# 웰바이오텍
# 스페코
# 유에스티
# 인산가
# 씨티알모빌리티
# 케일럼
# 우성
# 동우팜투테이블
# 에코캡
# 진매트릭스
# 동국알앤에스
# 푸드나무
# 자비스
# 엔피디
# 브레인즈컴퍼니
# 에쓰씨엔지니어링
# 뉴트리
# 유성기업
# 아시아경제
# 아센디오
# 비스토스
# 앱코
# 캡스톤파트너스
# TKG애강
# 롯데칠성우
# 한네트
# 상상인증권
# 큐캐피탈
# 원풍
# 케이씨피드
# 삼성스팩8호
# FSN
# 코스나인
# 한창제지
# 휴엠앤씨
# 케이피엠테크
# SJM홀딩스
# 신화인터텍
# SJM
# 엔에프씨
# 얼라인드
# 엠아이큐브솔루션
# 뱅크웨어글로벌
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 앤디포스
# 엑시큐어하이트론
# NHN벅스
# 파워넷
# 제이엔비
# 아이퀘스트
# 아이언디바이스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 바이오톡스텍
# 뷰티스킨
# 승일
# 큐라티스
# 와이즈버즈
# 플레이그램
# 남화토건
# 일신바이오
# 탑코미디어
# 진양화학
# 대신정보통신
# 진영
# NE능률
# 에스제이그룹
# 코맥스
# 코셈
# 모비릭스
# 케이탑리츠
# 우리산업홀딩스
# 포톤
# 옵트론텍
# 와이오엠
# 하나금융25호스팩
# 리더스코스메틱
# 영화금속
# 코이즈
# 네이블
# 쏘닉스
# 삼보산업
# RF머트리얼즈
# 세림B&G
# 쎄노텍
# 알피바이오
# 텔콘RF제약
# 마스턴프리미어리츠
# 팸텍
# 아세아텍
# PN풍년
# 자이글
# 아이톡시
# 국영지앤엠
# 씨큐브
# SK디스커버리우
# 본느
# 오브젠
# 서암기계공업
# KH 미래물산
# 케이디켐
# 대유에이텍
# 동일기연
# 디케이앤디
# 피코그램
# 삼일기업공사
# 오공
# 기가레인
# 네오펙트
# 오션인더블유
# 서연탑메탈
# 영림원소프트랩
# 대창스틸
# 네오티스
# 오텍
# 삼기
# 백금T&A
# 성우전자
# 이에이트
# 포인트모바일
# 엔텔스
# 엑셀세라퓨틱스
# 상신전자
# 비비씨
# 제놀루션
# 루멘스
# 한익스프레스
# 티엔엔터테인먼트
# 신진에스엠
# 서진오토모티브
# 피델릭스
# 원바이오젠
# 마이크로투나노
# 유화증권우
# 프로티아
# 소니드
# 우진플라임
# 한국맥널티
# YW
# 뉴온
# 비씨월드제약
# 에스켐
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 빛과전자
# 힘스
# 세우글로벌
# 에이치와이티씨
# 제이티
# 코퍼스코리아
# 서전기전
# 이지트로닉스
# 진양폴리
# 플래티어
# 썸에이지
# 이루온
# 유니온커뮤니티
# 듀오백
# SK케미칼우
# 엠브레인
# 영흥
# 소프트센
# 일진디스플
# 코리아에셋투자증권
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 신풍
# KBG
# 파버나인
# 아이즈비전
# 오하임앤컴퍼니
# 계양전기
# 드림인사이트
# 캐스텍코리아
# 모아텍
# 지니너스
# 남성
# 비큐AI
# 피씨디렉트
# 파인텍
# 카이노스메드
# 씨싸이트
# KB오토시스
# 포커스에이치엔에스
# 신라섬유
# 대성파인텍
# 씨유박스
# 씨유메디칼
# 링크드
# 모나미
# 한솔PNS
# 키네마스터
# 휴맥스홀딩스
# 모코엠시스
# 아이컴포넌트
# 제이엠티
# 와토스코리아
# 이원컴포텍
# 삼진
# 대한과학
# MH에탄올
# 이노룰스
# 서울제약
# 부산주공
# 윙스풋
# 한세엠케이
# 스킨앤스킨
# 폴라리스우노
# 유안타증권우
# 엔투텍
# 모아데이타
# 체리부로
# 피엔티엠에스
# 버넥트
# 신한제11호스팩
# 케이엠
# 미래산업
# 체시스
# 소프트캠프
# 이엔플러스
# 전방
# 나래나노텍
# 디티앤씨
# GH신소재
# 글로본
# 한국큐빅
# 삼성스팩7호
# 대원화성
# 케이씨티
# 대림통상
# 이씨에스
# SUN&L
# 포메탈
# 시지트로닉스
# 누보
# 에스에이티
# 한창산업
# 오디텍
# DL이앤씨우
# 솔트웨어
# 스튜디오삼익
# 밸로프
# 디에이테크놀로지
# 지니틱스
# DH오토리드
# 동양파일
# 우리이앤엘
# 이화공영
# 삼일
# 핌스
# 아우딘퓨쳐스
# 메디앙스
# 배럴
# 빛샘전자
# 한일화학
# 이노시뮬레이션
# 엠에프씨
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 유투바이오
# 메타랩스
# 윈하이텍
# 손오공
# 핸즈코퍼레이션
# 에이텀
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 케이웨더
# 신화콘텍
# 휴림에이텍
# 헝셩그룹
# 아이윈
# 아이크래프트
# 유디엠텍
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 아이앤씨
# DH오토웨어
# ES큐브
# 엔젠바이오
# 파인디지털
# CS
# 무림SP
# 한빛소프트
# 제주맥주
# 휴네시온
# 시큐브
# 세화피앤씨
# 국보
# 아이윈플러스
# 케이쓰리아이
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 누리플렉스
# 디지캡
# TPC
# 원림
# 조아제약
# 신원종합개발
# 코아스
# 에스폴리텍
# 대성미생물
# DL우
# 아이비젼웍스
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에스에너지
# 한성기업
# 알티캐스트
# 그린생명과학
# 나노
# 케이바이오
# 한국전자홀딩스
# 오스템
# 원일특강
# 나라셀라
# 멕아이씨에스
# 기산텔레콤
# 바이오인프라
# 디와이씨
# WISCOM
# 웰크론한텍
# 바른손이앤에이
# 프리시젼바이오
# 미래아이앤지
# 진바이오텍
# 비비안
# 경인전자
# 넥스턴바이오
# 로지시스
# TS트릴리온
# 이스트아시아홀딩스
# 율촌
# 이화산업
# 유진테크놀로지
# 엑스큐어
# 토박스코리아
# 압타머사이언스
# 셀피글로벌
# 한주라이트메탈
# 제이준코스메틱
# 온타이드
# 솔루스첨단소재1우
# KC코트렐
# 신도기연
# S&K폴리텍
# 피엠티
# 엔에이치스팩29호
# BYC우
# DGP
# 태원물산
# 제넨바이오
# SGA솔루션즈
# 크린앤사이언스
# 하이즈항공
# 바른손
# 부스타
# 한화투자증권우
# 성우테크론
# 코아시아씨엠
# 레이저쎌
# 팜스빌
# 리튬포어스
# 아즈텍WB
# 정원엔시스
# 피앤씨테크
# KR모터스
# 제이에스티나
# 화인베스틸
# 세중
# 제이엠아이
# 젠큐릭스
# 에스티오
# 대한방직
# 에스씨엠생명과학
# 세기상사
# 우리엔터프라이즈
# 딜리
# 세방우
# 인바이오
# 티에스넥스젠
# 비엘팜텍
# 휴럼
# 플레이위드
# 엑사이엔씨
# 에이에프더블류
# 선샤인푸드
# 판타지오
# 동양에스텍
# 이엠앤아이
# 동일제강
# 에스앤더블류
# 영우디에스피
# 브이씨
# 신시웨이
# 이미지스
# 신라에스지
# 알로이스
# 위니아에이드
# 한국정밀기계
# 서산
# 비피도
# 성창오토텍
# 풍강
# 대교우B
# 신풍제약우
# KB제27호스팩
# 한솔인티큐브
# 나노씨엠에스
# 우진비앤지
# 성문전자
# 유비온
# 엔시트론
# 시큐센
# 우정바이오
# 다이나믹디자인
# 미코바이오메드
# 대한제당우
# 에스엘에스바이오
# 아시아종묘
# 디모아
# 핀텔
# 에스디시스템
# BF랩스
# 뉴보텍
# 뉴인텍
# 대한항공우
# 참엔지니어링
# 오에스피
# 진도
# 디에이치엑스컴퍼니
# 셀레믹스
# 스튜디오산타클로스
# 메디콕스
# 동원수산
# 주연테크
# 한탑
# 삼영에스앤씨
# 대상우
# 지란지교시큐리티
# 한창
# 호텔신라우
# 대산F&B
# 글로벌에스엠
# 세종메디칼
# TBH글로벌
# 두산퓨얼셀2우B
# 패션플랫폼
# 인콘
# 이노진
# 하이퍼코퍼레이션
# 대신밸런스제15호스팩
# 육일씨엔에쓰
# KD
# 라닉스
# 삼성스팩9호
# 태양금속우
# 한국정보공학
# 알파녹스
# 위니아
# 전진바이오팜
# 인터엠
# 나노캠텍
# THE E&M
# 한국유니온제약
# 해성옵틱스
# 웹스
# 티피씨글로벌
# 동일스틸럭스
# 비유테크놀러지
# 플루토스
# 누리플랜
# 에이치케이
# 파루
# 한국주강
# 에이엔피
# 파인테크닉스
# 엔피케이
# 대호특수강
# 이퓨쳐
# 대동금속
# 동양고속
# 유아이디
# 씨엔플러스
# 애드바이오텍
# 롯데지주우
# 유안타제13호스팩
# 우진아이엔에스
# 비츠로시스
# 네오리진
# 삼진엘앤디
# SGA
# 스타플렉스
# 로스웰
# 골드앤에스
# 이엘피
# 세진티에스
# 알톤
# 플라즈맵
# 에스아이리소스
# 세니젠
# 원풍물산
# 국일신동
# 벨로크
# 다산솔루에타
# LX하우시스우
# SHD
# 에스에스알
# 엔에이치스팩26호
# 베셀
# 이노인스트루먼트
# 한국ANKOR유전
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 세동
# 에프알텍
# 빌리언스
# 엔에이치스팩30호
# 웰킵스하이텍
# 케스피온
# 대상홀딩스우
# 오가닉티코스메틱
# 솔루스첨단소재2우B
# 피씨엘
# 삼양홀딩스우
# 녹십자홀딩스2우
# KC그린홀딩스
# 케이피티유
# 성신양회우
# 코리아써우
# 디지아이
# 엘디티
# 하이트진로2우B
# 케이엠제약
# 넥센타이어1우B
# 한국제14호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 엔에이치스팩27호
# 더코디
# 대신밸런스제18호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 미래에셋비전스팩7호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 씨엑스아이
# 미래에셋비전스팩4호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 스타에스엠리츠
# 노블엠앤비
# 대덕전자1우
# 코오롱우
# 앤씨앤
# 예선테크
# 대신밸런스제16호스팩
# 큐로홀딩스
# 파커스
# 에이치엠씨제7호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 퀀텀온
# 광진실업
# 하나30호스팩
# 하나28호스팩
# 인베니아
# 대신밸런스제14호스팩
# 신영스팩8호
# 서울전자통신
# 비케이홀딩스
# 오늘이엔엠
# 에이리츠
# 유안타제15호스팩
# 한국제15호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 미래에셋비전스팩6호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 지엔코
# 덕성우
# 셀레스트라
# 바이온
# 드래곤플라이
# 한주에이알티
# 일정실업
# 키움제11호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 대신밸런스제17호스팩
# 키움제8호스팩
# KB제29호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 엔에이치스팩31호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# JW중외제약2우B
# 디비금융제13호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에이디칩스
# 하나26호스팩
# NPC우
# KB제31호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 교보16호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# KB제28호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 삼영이엔씨
# DB금융스팩12호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 유안타제10호스팩
# 유유제약1우
# DB금융스팩11호
# 하나27호스팩
# 흥국화재우
# 한진칼우
# LX홀딩스1우
# 신영스팩9호
# 넥센우
# 장원테크
# 대신밸런스제19호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 신한제12호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 신한제14호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하나29호스팩
# 하나31호스팩
# 삼양사우
# 코오롱글로벌우
# 미래에셋비전스팩5호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 유안타제16호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# KB제30호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 엔에이치스팩24호
# 미래에셋비전스팩2호
# 유안타제17호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 유안타제11호스팩
# 상상인제4호스팩
# 미래에셋비전스팩3호
# 교보17호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 유안타제12호스팩
# 하이제8호스팩
# 에스케이증권제9호스팩
# 한화플러스제4호스팩
# 이베스트스팩6호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 신영스팩10호
# 한화플러스제5호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# IBKS제22호스팩
# 대원전선우
# 대덕1우
# JW중외제약우
# 유진스팩11호
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해성산업1우
# IBKS제21호스팩
# 유안타제14호스팩
# 하나34호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 한국제12호스팩
# 한국제13호스팩
# IBKS제20호스팩
# 비엔케이제1호스팩
# 크라운제과우
# IBKS제23호스팩
# KB제25호스팩
# 에스케이증권제13호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 유진스팩10호
# IBKS제24호스팩
# 교보14호스팩
# 키움제10호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 신한제15호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에이치엠씨제6호스팩
# 교보13호스팩
# 에스케이증권제11호스팩
# 비엔케이제2호스팩
# 한화우
# 교보15호스팩
# 하나33호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 에스케이증권제8호스팩
# 올리패스
# 코오롱모빌리티그룹우
# 신한제13호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 노루홀딩스우
# 유진스팩9호
# 한양증권우
# 엠에프엠코리아
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# SK증권우
# 한화갤러리아우
# 투비소프트
# 에스케이증권제10호스팩
# 에스케이증권제12호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 하나32호스팩
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 깨끗한나라우
# 노루페인트우
# 엔에이치스팩25호
# 스타코링크
# 크라운해태홀딩스우
# 일양약품우
# 티와이홀딩스우
# 아이엠
# 하이트진로홀딩스우
# 더테크놀로지
# 동원시스템즈우
# 남선알미우
# 계양전기우
# 동부건설우
# 코리아써키트2우B
# 금강공업우
# CNH
# CJ씨푸드1우
# 유유제약2우B
# 금호건설우
# 태영건설우
# 진흥기업2우B
# 진흥기업우B
# 서울식품우
# 성문전자우
# 동양우
# 동양2우B
# 소프트센우
# 대호특수강우

# %% [markdown]
# ### 4. 데이터 정제

# %%
data.drop_duplicates(inplace = True)
data.sort_values(by = ['기업', '연도'], inplace = True)

# %%
display(data.head())
# Out:
#           기업    연도               자산총계             부채총계             자본총계  \
# 7250      3S  2021     54,614,752,349   18,068,427,911   36,546,324,438
# 7249      3S  2022     65,127,864,527   26,788,875,680   38,338,988,847
# 7248      3S  2023     67,635,499,845   21,680,745,544   45,954,754,301
# 7251      3S  2024     63,790,941,612   15,350,773,617   48,440,167,995
# 5684  AJ네트웍스  2021  1,356,987,456,278  992,584,894,057  364,402,562,221
#
#                   매출액            영업이익           당기순이익
# 7250   23,477,908,383  -1,408,265,950     695,334,883
# 7249   27,110,628,415   1,452,134,065   1,171,369,995
# 7248   41,857,755,025   2,180,508,808   1,431,602,721
# 7251   43,595,351,592   1,164,030,344   2,605,084,717
# 5684  981,947,656,833  48,071,717,838  76,737,133,075

# %%
# 숫자로 모두 변환
def convert_str_to_float(value):
    if type(value) == float: # nan의 자료형은 float임
        return value
    elif value == '-': # -로 되어 있으면 0으로 변환
        return 0
    else:
        return float(value.replace(',', ''))

for ind in ind_list:
    data[ind] = data[ind].apply(convert_str_to_float)

# %%
display(data.head())
# Out:
#           기업    연도          자산총계          부채총계          자본총계           매출액  \
# 7250      3S  2021  5.461475e+10  1.806843e+10  3.654632e+10  2.347791e+10
# 7249      3S  2022  6.512786e+10  2.678888e+10  3.833899e+10  2.711063e+10
# 7248      3S  2023  6.763550e+10  2.168075e+10  4.595475e+10  4.185776e+10
# 7251      3S  2024  6.379094e+10  1.535077e+10  4.844017e+10  4.359535e+10
# 5684  AJ네트웍스  2021  1.356987e+12  9.925849e+11  3.644026e+11  9.819477e+11
#
#               영업이익         당기순이익
# 7250 -1.408266e+09  6.953349e+08
# 7249  1.452134e+09  1.171370e+09
# 7248  2.180509e+09  1.431603e+09
# 7251  1.164030e+09  2.605085e+09
# 5684  4.807172e+10  7.673713e+10

# %% [markdown]
# ### 5. 주요 지표 계산

# %% [markdown]
# #### 부채비율

# %%
data['부채비율'] = data['부채총계'] / data['자본총계'] * 100
display(data['부채비율'].head())
# Out:
# 7250     49.439795
# 7249     69.873715
# 7248     47.178460
# 7251     31.690174
# 5684    272.386914
# Name: 부채비율, dtype: float64

# %% [markdown]
# #### 매출액 증가율, 영업이익 증가율, 당기순이익 증가율

# %%
data['매출액증가율'] = (data['매출액'].diff() / data['매출액'].shift(1)) * 100
data.loc[data['연도'] == 2013, '매출액증가율'] = np.nan

# %%
data['영업이익증가율'] = (data['영업이익'].diff() / data['영업이익'].shift(1)) * 100
data.loc[data['연도'] == 2013, '영업이익증가율'] = np.nan

data['당기순이익증가율'] = (data['당기순이익'].diff() / data['당기순이익'].shift(1)) * 100
data.loc[data['연도'] == 2013, '당기순이익증가율'] = np.nan

# %%
data = data.replace({np.inf:np.nan, -np.inf: np.nan})

# %% [markdown]
# #### 매출액 상태, 영업이익 상태, 당기순이익 상태

# %%
# 상태를 나타내는 함수 정의
def add_state(data, col):
    data[col + "_상태"] = np.nan # 상태를 결측으로 초기화
    value = data[col].values
    cur_value = value[1:]
    pre_value = value[:-1]
    # 흑자지속
    cond1 = (cur_value > 0) & (pre_value > 0)
    cond1 = np.insert(cond1, 0, np.nan)
    # 적자지속
    cond2 = (cur_value <= 0) & (pre_value <= 0)
    cond2 = np.insert(cond2, 0, np.nan)
    # 흑자전환
    cond3 = (cur_value > 0) & (pre_value <= 0)
    cond3 = np.insert(cond3, 0, np.nan)
    # 적자전환
    cond4 = (cur_value <= 0) & (pre_value > 0)
    cond4 = np.insert(cond4, 0, np.nan)

    # 조건에 따른 변환
    data.loc[cond1, col + "_상태"] = "흑자지속"
    data.loc[cond2, col + "_상태"] = "적자지속"
    data.loc[cond3, col + "_상태"] = "흑자전환"
    data.loc[cond4, col + "_상태"] = "적자전환"

# %%
add_state(data, "매출액")
add_state(data, "영업이익")
add_state(data, "당기순이익")
# Out:
# <ipython-input-18-179a2f83036a>:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '흑자지속' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[cond1, col + "_상태"] = "흑자지속"
# <ipython-input-18-179a2f83036a>:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '흑자지속' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[cond1, col + "_상태"] = "흑자지속"
# <ipython-input-18-179a2f83036a>:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '흑자지속' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[cond1, col + "_상태"] = "흑자지속"

# %% [markdown]
# #### ROA

# %%
data['ROA'] = (data['당기순이익'] / data['자산총계']) * 100

# %% [markdown]
# #### ROE

# %%
average_equity = data['자본총계'].rolling(2).mean() # 평균 자기 자본
data['ROE'] = (data['당기순이익'] / average_equity) * 100
data.loc[data['연도'] == 2013, 'ROE'] = np.nan

# %% [markdown]
# #### 데이터 저장

# %%
data.to_csv("./data/주요재무지표_수정.csv", index = False, encoding = "utf-8")
display(data)
# Out:
#            기업    연도          자산총계          부채총계          자본총계           매출액  \
# 7250       3S  2021  5.461475e+10  1.806843e+10  3.654632e+10  2.347791e+10
# 7249       3S  2022  6.512786e+10  2.678888e+10  3.833899e+10  2.711063e+10
# 7248       3S  2023  6.763550e+10  2.168075e+10  4.595475e+10  4.185776e+10
# 7251       3S  2024  6.379094e+10  1.535077e+10  4.844017e+10  4.359535e+10
# 5684   AJ네트웍스  2021  1.356987e+12  9.925849e+11  3.644026e+11  9.819477e+11
# ...       ...   ...           ...           ...           ...           ...
# 9759       희림  2024  2.082984e+11  1.261688e+11  8.212957e+10  2.409611e+11
# 13046      힘스  2021  8.430302e+10  1.038679e+10  7.391623e+10           NaN
# 13045      힘스  2022  7.952340e+10  1.758886e+10  6.193453e+10           NaN
# 13044      힘스  2023  9.559763e+10  2.706650e+10  6.853113e+10           NaN
# 13047      힘스  2024  8.668104e+10  1.599411e+10  7.068693e+10           NaN
#
#                영업이익         당기순이익        부채비율       매출액증가율      영업이익증가율  \
# 7250  -1.408266e+09  6.953349e+08   49.439795          NaN          NaN
# 7249   1.452134e+09  1.171370e+09   69.873715    15.472929  -203.115045
# 7248   2.180509e+09  1.431603e+09   47.178460    54.396108    50.158919
# 7251   1.164030e+09  2.605085e+09   31.690174     4.151194   -46.616572
# 5684   4.807172e+10  7.673713e+10  272.386914  2152.413666  4029.765009
# ...             ...           ...         ...          ...          ...
# 9759   1.527903e+10  1.342837e+10  153.621647     5.383212   107.135232
# 13046 -4.371187e+09 -4.413924e+08   14.052104          NaN  -128.609063
# 13045 -1.327548e+10 -8.645207e+09   28.399120          NaN   203.704340
# 13044  5.685407e+09  5.599495e+09   39.495187          NaN  -142.826362
# 13047  1.686902e+08  2.710626e+09   22.626693          NaN   -97.032926
#
#           당기순이익증가율 매출액_상태 영업이익_상태 당기순이익_상태        ROA        ROE
# 7250           NaN   적자전환    적자전환     적자전환   1.273163        NaN
# 7249     68.461273   흑자지속    흑자전환     흑자지속   1.798570   3.128437
# 7248     22.216100   흑자지속    흑자지속     흑자지속   2.116644   3.396700
# 7251     81.969808   흑자지속    흑자지속     흑자지속   4.083785   5.519544
# 5684   2845.667470   흑자지속    흑자지속     흑자지속   5.654963  37.174995
# ...            ...    ...     ...      ...        ...        ...
# 9759    110.558954   흑자지속    흑자지속     흑자지속   6.446699  17.280208
# 13046  -103.287015    NaN    적자전환     적자전환  -0.523578  -0.565722
# 13045  1858.621469    NaN    적자지속     적자지속 -10.871275 -12.727505
# 13044  -164.769937    NaN    흑자전환     흑자전환   5.857358   8.583860
# 13047   -51.591600    NaN    흑자지속     흑자지속   3.127127   3.894073
#
# [11246 rows x 17 columns]
